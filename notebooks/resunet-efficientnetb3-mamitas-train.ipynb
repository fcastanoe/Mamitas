# %% [markdown]
# ### **Descarga e importe de bibliotecas**

# %%
# %%capture
# !pip install git+https://github.com/qubvel/classification_models.git

# %%
import os
os.environ["TF_USE_LEGACY_KERAS"]="1"

# %%
import gc
import re
import glob
import random
import shutil
import zipfile
import numpy as np
from functools import partial
import matplotlib.pyplot as plt

import tensorflow as tf
import tf_keras as keras
import tf_keras.backend as K
from tf_keras.losses import Loss
from tf_keras.layers import Layer
from tf_keras import layers, Model
from tf_keras.optimizers import Adam
from tf_keras.callbacks import Callback
from tf_keras.applications import EfficientNetB3
from tf_keras.saving import register_keras_serializable

# ResUNet Model Backbone
from classification_models.tfkeras import Classifiers  # Requires: pip install git+https://github.com/qubvel/classification_models.git
# Out:
# 2025-04-12 02:39:05.628874: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744425546.086829      31 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744425546.220230      31 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# ### **Configuración del entorno**

# %%
# Set a seed
seed = 42

np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

# %%
# Create a distribution strategy
strategy = tf.distribute.MirroredStrategy()
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# Out:
# Number of devices: 2
# I0000 00:00:1744425578.362330      31 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1744425578.363045      31 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5

# %% [markdown]
# ### **Descarga y cargado de la base de datos de mamitas**

# %% [markdown]
# ##### **Importante definir el número de clases**

# %%
classes = 2 # Son dos clases; 0-Fondo, 1-feet

# %%
shutil.copytree('/kaggle/input/mamitas-only-subject', '/kaggle/working/datasets/Mamitas_')
# Out:
# '/kaggle/working/datasets/Mamitas_'

# %%
config = {"Seg_model":"ResUNet","Activation":"softmax","Input size":(512,512,3),"Image size":(512,512),
          "Dataset":"Mamitas_","Dir of dataset":"./datasets/Mamitas_","Batch size":16,"Epochs":100,"Number of classes":classes}

# %%
class DataLoader:

    def __init__(self, data_dir, batch_size, image_size, num_classes, partition):

        self.data_dir = data_dir
        self.batch_size = batch_size
        self.image_size = image_size
        self.num_classes = num_classes
        self.partition = partition

    def load_images(self):

        # Create the path for patch images
        images_path_pattern = os.path.join(self.data_dir, self.partition, 'images', '*.png')
        images_files = glob.glob(images_path_pattern)

        # Sort patch files alphanumerically
        def alphanumeric_key(s):
            # Split the string into parts (numbers and text)
            parts = re.split(r'(\d+)', s)
            # Convert numeric parts to integers for proper sorting
            return [int(part) if part.isdigit() else part for part in parts]

        images_files = sorted(images_files, key=alphanumeric_key)

        self.file_sample = []
        for file in images_files:
            name_file = file.split('/')[-1]
            self.file_sample.append(name_file)

        self.num_samples = len(images_files)

        # Print the complete path and the number of found patch images
        print(f"Complete images: {images_path_pattern}")
        print(f"Number of images files found: {len(images_files)}")

        # Create a TensorFlow dataset from the images file paths
        images_ds = tf.data.Dataset.from_tensor_slices(images_files)

        # Map each file path to a processed image
        images_ds = images_ds.map(self.process_images, num_parallel_calls=tf.data.AUTOTUNE)

        return images_ds

    def load_masks(self):

        mask_path_main = os.path.join(self.data_dir, self.partition, 'masks')

        # Check samples in classes
        for class_id in range(self.num_classes):
            mask_path_pattern = os.path.join(mask_path_main, f'class_{class_id}', '*.png')
            found_masks = glob.glob(mask_path_pattern)
            print(f"Original masks path, class {class_id}: {mask_path_pattern}")
            print(f"Number of masks found: {len(found_masks)}")

        masks_path = []
        # Organize ground truth masks by sample and class
        for sample in self.file_sample:
            masks_sample = []
            for class_id in range(self.num_classes):
                masks_sample.append(os.path.join(mask_path_main, f'class_{class_id}', sample))
            masks_path.append(masks_sample)

        # Create dataset from `masks_path` and apply `process_masks` to each set of paths
        masks_ds = tf.data.Dataset.from_tensor_slices(masks_path)
        masks_ds = masks_ds.map(self.process_masks, num_parallel_calls=tf.data.AUTOTUNE)

        return masks_ds

    def process_images(self, file_path):

        img = tf.io.read_file(file_path)  # Read the image file
        img = tf.image.decode_png(img, channels=3)  # Decode PNG image
        img = tf.image.resize(img, self.image_size)  # Resize image
        img = tf.cast(img, tf.float32)  # Convert to float32
        img /= 255.0  # Normalize to [0, 1]
        return img

    def process_masks(self, sample_paths):

        # Decode and process images
        decoded_images = tf.map_fn(
            tf.io.read_file,
            sample_paths,
            dtype=tf.string,
            parallel_iterations=4
        )

        masks = tf.map_fn(
            lambda x: tf.io.decode_png(x, channels=1),
            decoded_images,
            dtype=tf.uint8,
            parallel_iterations=4
        )

        # Resize and normalize
        masks = tf.map_fn(
            lambda x: tf.image.resize(x, size=self.image_size),
            masks,
            dtype=tf.float32
        )

        masks = tf.cast(masks, tf.float32)  # Convert to float32
        masks = masks / 255.0  # Normalize to [0, 1]
        masks = tf.squeeze(masks, axis=-1)  # Remove the last dimension
        masks = tf.transpose(masks, perm=[1, 2, 0])  # Transpose to [height, width, classes]

        return masks

    def get_dataset(self):

        images_ds = self.load_images()
        masks_ds = self.load_masks()
        dataset = tf.data.Dataset.zip((images_ds,masks_ds))

        # Apply batching and prefetching for optimization
        dataset = dataset.batch(self.batch_size)
        dataset = dataset.prefetch(tf.data.AUTOTUNE)

        return dataset

# %%
# Instantiate data loader and load train partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Train')
train_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Mamitas_/Train/images/*.png
# Number of images files found: 342
# Original masks path, class 0: ./datasets/Mamitas_/Train/masks/class_0/*.png
# Number of masks found: 342
# Original masks path, class 1: ./datasets/Mamitas_/Train/masks/class_1/*.png
# Number of masks found: 342

# %%
# Instantiate data loader and load validation partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Valid')
valid_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Mamitas_/Valid/images/*.png
# Number of images files found: 37
# Original masks path, class 0: ./datasets/Mamitas_/Valid/masks/class_0/*.png
# Number of masks found: 37
# Original masks path, class 1: ./datasets/Mamitas_/Valid/masks/class_1/*.png
# Number of masks found: 37

# %%
# Instantiate data loader and load test partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Test')
test_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Mamitas_/Test/images/*.png
# Number of images files found: 37
# Original masks path, class 0: ./datasets/Mamitas_/Test/masks/class_0/*.png
# Number of masks found: 37
# Original masks path, class 1: ./datasets/Mamitas_/Test/masks/class_1/*.png
# Number of masks found: 37

# %% [markdown]
# #### **Visualización de la base de datos de semillas**

# %%
def random_sample_visualization(dataset, num_classes):

    # Select first batch
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    # Determine the number of columns for the visualization grid
    columns = []
    rows = 2

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)

    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Masks of segmentation for different classes",loc='left')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(num_classes,columns):
        num = random.randint(0, num_classes-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(masks[sample, :, :, classes_list[i]:classes_list[i]+1])

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()

    # Free memory
    del images, masks # Delete large variables
    if 'annotators_list' in locals():
        del annotators_list
    if 'classes_list' in locals():
        del classes_list
    gc.collect() # Force garbage collection

# %%
random_sample_visualization(train_dataset, config['Number of classes'])
# Out:
# Images in the batch: (16, 512, 512, 3), Masks in the batch: (16, 512, 512, 2)
# /tmp/ipykernel_31/2758281868.py:46: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# ### **Definición y creación del modelo, medidas de rendimiento y función de pérdida**

# %%
ResNet34, preprocess_input = Classifiers.get('resnet34')

# Definition of layers for the neural network structure

DefaultConv2D = partial(layers.Conv2D,
                        kernel_size=3, activation='relu', padding="same")

DefaultPooling = partial(layers.MaxPool2D,
                        pool_size=2)


upsample = partial(layers.UpSampling2D, (2,2))

@register_keras_serializable(package="my_custom_losses")
class DiceCoefficient(Loss):
    def __init__(self, smooth=1., target_class= None, name='DiceCoefficient', **kwargs):
        self.smooth = smooth
        self.target_class = target_class
        super().__init__(name=name,**kwargs)

    def call(self, y_true, y_pred):
        intersection = K.sum(y_true * y_pred, axis=[1,2])
        union = K.sum(y_true,axis=[1,2]) + K.sum(y_pred,axis=[1,2])
        dice_coef = -(2. * intersection + self.smooth) /(union + self.smooth)
        
        if self.target_class != None:
            dice_coef = tf.gather(dice_coef,
                                  self.target_class, axis=1)
        else:
            dice_coef = K.mean(dice_coef,axis=-1)

        return dice_coef

    def get_config(self,):
        base_config = super().get_config()
        return {**base_config, "smooth": self.smooth,
                "target_class":self.target_class}

@register_keras_serializable(package="my_custom_metrics")
def dice_metric(y_true, y_pred, smooth=1e-7, axis=(1, 2), return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis)
    dice = (2. * intersection + smooth) / (union + smooth)

    if return_mean:
        return tf.reduce_mean(dice)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if dice.shape[1] > 1:
            return tf.transpose(dice, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(dice, perm=[1, 0]), axis=0)
            
@register_keras_serializable(package="my_custom_metrics")
def jaccard_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis) - intersection
    jaccard = (intersection + smooth) / (union + smooth)
    if return_mean:
        return tf.reduce_mean(jaccard)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if jaccard.shape[1] > 1:
            return tf.transpose(jaccard, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(jaccard, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def sensitivity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    actual_positives = tf.reduce_sum(y_true, axis=axis)
    sensitivity = true_positives / (actual_positives + smooth)
    if return_mean:
        return tf.reduce_mean(sensitivity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if sensitivity.shape[1] > 1:
            return tf.transpose(sensitivity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(sensitivity, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def specificity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_negatives = tf.reduce_sum((1 - y_true) * (1 - y_pred), axis=axis)
    actual_negatives = tf.reduce_sum(1 - y_true, axis=axis)
    specificity = true_negatives / (actual_negatives + tf.keras.backend.epsilon())
    if return_mean:
        return tf.reduce_mean(specificity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if specificity.shape[1] > 1:
            return tf.transpose(specificity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(specificity, perm=[1, 0]), axis=0)


@register_keras_serializable(package="my_custom_activations")
def sparse_softmax(x):
    
    e_x = tf.exp(x - tf.reduce_max(x, axis=-1, keepdims=True))
    sum_e_x = tf.reduce_sum(e_x, axis=-1, keepdims=True)
    output = e_x / (sum_e_x + keras.backend.epsilon())
    return output

def kernel_initializer(seed):
    
    return tf.keras.initializers.GlorotUniform(seed=seed)


def residual_block(x, filters, kernel_initializer, block_name):
    
    shortcut = x
    x = DefaultConv2D(filters, kernel_initializer=kernel_initializer, name=f'Conv_{block_name}_1')(x)
    x = layers.BatchNormalization(name=f'Batch_{block_name}_1')(x)
    x = DefaultConv2D(filters, kernel_initializer=kernel_initializer, name=f'Conv_{block_name}_2')(x)
    x = layers.BatchNormalization(name=f'Batch_{block_name}_2')(x)
    x = layers.Add(name=f'ResAdd_{block_name}')([shortcut, x])
    x = layers.Activation('relu', name=f'ResAct_{block_name}')(x)
    return x

def UNet(inputs, out_channels, activation):
    
    # Encoder - Downsampling path with increasing filter numbers
    # Each level follows: Conv -> Dropout -> BatchNorm -> Conv -> Dropout -> BatchNorm -> Pooling

    x = layers.BatchNormalization(name='Batch00')(inputs)
    x = DefaultConv2D(8, kernel_initializer=kernel_initializer(34), name='Conv10')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch10')(x)
    x = level_1 = DefaultConv2D(8, kernel_initializer=kernel_initializer(4), name='Conv11')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch11')(x)
    x = DefaultPooling(name='Pool10')(x)  # 128x128 -> 64x64

    x = DefaultConv2D(16, kernel_initializer=kernel_initializer(56), name='Conv20')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch20')(x)
    x = level_2 = DefaultConv2D(16, kernel_initializer=kernel_initializer(32), name='Conv21')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch22')(x)
    x = DefaultPooling(name='Pool20')(x)  # 64x64 -> 32x32

    x = DefaultConv2D(32, kernel_initializer=kernel_initializer(87), name='Conv30')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch30')(x)
    x = level_3 = DefaultConv2D(32, kernel_initializer=kernel_initializer(30), name='Conv31')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch31')(x)
    x = DefaultPooling(name='Pool30')(x)  # 32x32 -> 16x16

    x = DefaultConv2D(64, kernel_initializer=kernel_initializer(79), name='Conv40')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch40')(x)
    x = level_4 = DefaultConv2D(64, kernel_initializer=kernel_initializer(81), name='Conv41')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch41')(x)
    x = DefaultPooling(name='Pool40')(x)  # 16x16 -> 8x8

    # Decoder - Upsampling path with decreasing filter numbers
    # Each level follows: Conv -> Dropout -> BatchNorm -> Conv -> Dropout -> BatchNorm
    x = DefaultConv2D(128, kernel_initializer=kernel_initializer(89), name='Conv50')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch50')(x)
    x = DefaultConv2D(128, kernel_initializer=kernel_initializer(42), name='Conv51')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch51')(x)

    # Upsampling and skip connection with level_4 features
    x = upsample(name='Up60')(x)  # 8x8 -> 16x16
    x = layers.Concatenate(name='Concat60')([level_4, x])
    x = DefaultConv2D(64, kernel_initializer=kernel_initializer(91), name='Conv60')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch60')(x)
    x = DefaultConv2D(64, kernel_initializer=kernel_initializer(47), name='Conv61')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch61')(x)

    # Upsampling and skip connection with level_3 features
    x = upsample(name='Up70')(x)  # 16x16 -> 32x32
    x = layers.Concatenate(name='Concat70')([level_3, x])
    x = DefaultConv2D(32, kernel_initializer=kernel_initializer(21), name='Conv70')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch70')(x)
    x = DefaultConv2D(32, kernel_initializer=kernel_initializer(96), name='Conv71')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch71')(x)

    # Upsampling and skip connection with level_2 features
    x = upsample(name='Up80')(x)  # 32x32 -> 64x64
    x = layers.Concatenate(name='Concat80')([level_2, x])
    x = DefaultConv2D(16, kernel_initializer=kernel_initializer(96), name='Conv80')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch80')(x)
    x = DefaultConv2D(16, kernel_initializer=kernel_initializer(98), name='Conv81')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch81')(x)

    # Upsampling and skip connection with level_1 features
    x = upsample(name='Up90')(x)  # 64x64 -> 128x128
    x = layers.Concatenate(name='Concat90')([level_1, x])
    x = DefaultConv2D(8, kernel_initializer=kernel_initializer(35), name='Conv90')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch90')(x)
    x = DefaultConv2D(8, kernel_initializer=kernel_initializer(7), name='Conv91')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch91')(x)

    # Final segmentation output with specified activation
    if activation == 'sparse_softmax':
        x = DefaultConv2D(out_channels, kernel_size=(1, 1), activation=sparse_softmax,
                          kernel_initializer=kernel_initializer(42), name='Conv200')(x)
    else:
        x = DefaultConv2D(out_channels, kernel_size=(1, 1), activation=activation,
                          kernel_initializer=kernel_initializer(42), name='Conv200')(x)

    return x


def ResUNet(inputs, input_shape, out_channels,activation):
    
    # Backbone (EfficientNetB3) - Use pre-trained weights from ImageNet
    backbone = EfficientNetB3(
        input_shape=input_shape,
        input_tensor=inputs,
        include_top=False,
        weights='imagenet')
    
    # Freeze backbone layers except BatchNormalization layers
    for layer in backbone.layers:
        if not isinstance(layer, layers.BatchNormalization):
            layer.trainable = False

    # Extract feature maps from different levels of the EfficientNetB3 backbone
    level_1 = backbone.get_layer('block2a_expand_activation').output  # Example: initial output
    level_2 = backbone.get_layer('block3a_expand_activation').output  # Example: intermediate output 1
    level_3 = backbone.get_layer('block4a_expand_activation').output  # Example: intermediate output 2
    level_4 = backbone.get_layer('block6a_expand_activation').output  # Example: intermediate output 3
    x       = backbone.get_layer('top_activation').output            # Last output (8x8 or similar)

    # Decoder - Upsampling path with skip connections to encoder features
    # First upsampling block
    x = upsample(name='Up60')(x)
    x = layers.Concatenate(name='Concat60')([level_4, x])
    x = DefaultConv2D(256, kernel_initializer=kernel_initializer(91) , name='Conv60')(x)
    x = residual_block(x, 256, kernel_initializer(47), '60')  # Apply residual block

    # Second upsampling block
    x = upsample(name='Up70')(x)
    x = layers.Concatenate(name='Concat70')([level_3, x])
    x = DefaultConv2D(128, kernel_initializer=kernel_initializer(21), name='Conv70')(x)
    x = residual_block(x, 128, kernel_initializer(96), '70')  # Apply residual block

    # Third upsampling block
    x = upsample(name='Up80')(x)
    x = layers.Concatenate(name='Concat80')([level_2, x])
    x = DefaultConv2D(64, kernel_initializer=kernel_initializer(96), name='Conv80')(x)
    x = residual_block(x, 64, kernel_initializer(98), '80')  # Apply residual block

    # Fourth upsampling block
    x = upsample(name='Up90')(x)
    x = layers.Concatenate(name='Concat90')([level_1, x])
    x = DefaultConv2D(32, kernel_initializer=kernel_initializer(35), name='Conv90')(x)
    x = residual_block(x, 32, kernel_initializer(7), '90')  # Apply residual block

    # Final upsampling block - connect back to input
    x = upsample(name='Up100')(x)
    x = layers.Concatenate(name='Concat100')([inputs, x])
    x = DefaultConv2D(16, kernel_initializer=kernel_initializer(45), name='Conv100')(x)
    x = residual_block(x, 16, kernel_initializer(7), '100')  # Apply residual block

    # Final segmentation output with specified activation
    if activation == 'sparse_softmax':
        x = DefaultConv2D(out_channels, kernel_size=(1, 1), activation=sparse_softmax,
                          kernel_initializer=kernel_initializer(42), name='Conv200')(x)
    else:
        x = DefaultConv2D(out_channels, kernel_size=(1, 1), activation=activation,
                          kernel_initializer=kernel_initializer(42), name='Conv200')(x)

    return x

def Seg_Model(class_no=2, input_shape=(512, 512, 3), seg_model='ResUNet', activation='softmax'):
    
    # Input layer definition
    image_input = layers.Input(shape=input_shape, name='image_input')

    # Select and build the appropriate segmentation backbone
    if seg_model == 'ResUNet':
        # Use ResNet-based UNet architecture
        seg_rm = ResUNet(image_input, input_shape, out_channels=class_no, activation=activation)
    elif seg_model == 'UNet':
        # Use standard UNet architecture
        seg_rm = UNet(image_input, out_channels=class_no, activation=activation)
    else:
        # Raise error for unsupported model types
        raise ValueError(f"Unsupported segmentation model type: {seg_model}. Supported models are 'ResUNet' and 'UNet'.")

    # Create and return the final model
    return Model(image_input, seg_rm, name=seg_model)

# %%
with strategy.scope():
    model = Seg_Model(class_no=config['Number of classes'],input_shape=config['Input size'], 
                 seg_model=config['Seg_model'], activation=config['Activation'])
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-4),
                  loss=DiceCoefficient(smooth=1e-7, target_class=None if config['Number of classes'] == 3 else 1),
                  metrics=[dice_metric,jaccard_metric,sensitivity_metric,specificity_metric])
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb3_notop.h5
# 43941136/43941136 [==============================] - 0s 0us/step

# %% [markdown]
# ### **Entrenamiento de la base de datos**

# %%
class CustomLearningRateScheduler(Callback):
    def __init__(self, new_lr, epoch_to_change):
        super(CustomLearningRateScheduler, self).__init__()
        self.new_lr = new_lr
        self.epoch_to_change = epoch_to_change

    def on_epoch_begin(self, epoch, logs=None):
        if epoch == self.epoch_to_change:
            tf.keras.backend.set_value(self.model.optimizer.learning_rate, self.new_lr)
            print(f"Learning rate changed to {self.new_lr} at epoch {epoch}") 

lr_scheduler = CustomLearningRateScheduler(1e-5, 50)
history = model.fit(train_dataset, epochs=config['Epochs'], validation_data=(valid_dataset), callbacks=[lr_scheduler])
# Out:
# Epoch 1/100
# 22/22 [==============================] - 43s 2s/step - loss: -0.7637 - dice_metric: 0.8497 - jaccard_metric: 0.7550 - sensitivity_metric: 0.8616 - specificity_metric: 0.8616 - val_loss: -3.1144e-05 - val_dice_metric: 0.4304 - val_jaccard_metric: 0.3794 - val_sensitivity_metric: 0.5000 - val_specificity_metric: 0.5000
# Epoch 2/100
# 22/22 [==============================] - 29s 1s/step - loss: -0.8670 - dice_metric: 0.9157 - jaccard_metric: 0.8529 - sensitivity_metric: 0.9195 - specificity_metric: 0.9195 - val_loss: -5.5054e-05 - val_dice_metric: 0.4304 - val_jaccard_metric: 0.3794 - val_sensitivity_metric: 0.5000 - val_specificity_metric: 0.5000
# Epoch 3/100
# 22/22 [==============================] - 29s 1s/step - loss: -0.9266 - dice_metric: 0.9537 - jaccard_metric: 0.9149 - sensitivity_metric: 0.9535 - specificity_metric: 0.9535 - val_loss: -9.5286e-05 - val_dice_metric: 0.4304 - val_jaccard_metric: 0.3794 - val_sensitivity_metric: 0.5000 - val_specificity_metric: 0.5000
# Epoch 4/100
# 22/22 [==============================] - 28s 1s/step - loss: -0.9439 - dice_metric: 0.9642 - jaccard_metric: 0.9334 - sensitivity_metric: 0.9641 - specificity_metric: 0.9641 - val_loss: -2.3463e-04 - val_dice_metric: 0.4304 - val_jaccard_metric: 0.3794 - val_sensitivity_metric: 0.5000 - val_specificity_metric: 0.5000
# Epoch 5/100
# 22/22 [==============================] - 29s 1s/step - loss: -0.9606 - dice_metric: 0.9750 - jaccard_metric: 0.9521 - sensitivity_metric: 0.9746 - specificity_metric: 0.9746 - val_loss: -0.0221 - val_dice_metric: 0.4406 - val_jaccard_metric: 0.3853 - val_sensitivity_metric: 0.5050 - val_specificity_metric: 0.5050
# Epoch 6/100
# 22/22 [==============================] - 30s 1s/step - loss: -0.9669 - dice_metric: 0.9793 - jaccard_metric: 0.9601 - sensitivity_metric: 0.9790 - specificity_metric: 0.9790 - val_loss: -0.0697 - val_dice_metric: 0.4704 - val_jaccard_metric: 0.4038 - val_sensitivity_metric: 0.5209 - val_specificity_metric: 0.5209
# Epoch 7/100
# 22/22 [==============================] - 29s 1s/step - loss: -0.9713 - dice_metric: 0.9818 - jaccard_metric: 0.9648 - sensitivity_metric: 0.9822 - specificity_metric: 0.9822 - val_loss: -0.1117 - val_dice_metric: 0.4914 - val_jaccard_metric: 0.4175 - val_sensitivity_metric: 0.5324 - val_specificity_metric: 0.5324
# Epoch 8/100
# 22/22 [==============================] - 29s 1s/step - loss: -0.9730 - dice_metric: 0.9831 - jaccard_metric: 0.9673 - sensitivity_metric: 0.9833 - specificity_metric: 0.9833 - val_loss: -0.1964 - val_dice_metric: 0.5364 - val_jaccard_metric: 0.4493 - val_sensitivity_metric: 0.5594 - val_specificity_metric: 0.5594
# Epoch 9/100
# 22/22 [==============================] - 30s 1s/step - loss: -0.9743 - dice_metric: 0.9838 - jaccard_metric: 0.9685 - sensitivity_metric: 0.9832 - specificity_metric: 0.9832 - val_loss: -0.3262 - val_dice_metric: 0.6077 - val_jaccard_metric: 0.5063 - val_sensitivity_metric: 0.6076 - val_specificity_metric: 0.6076
# Epoch 10/100
# 22/22 [==============================] - 29s 1s/step - loss: -0.9744 - dice_metric: 0.9839 - jaccard_metric: 0.9689 - sensitivity_metric: 0.9843 - specificity_metric: 0.9843 - val_loss: -0.2593 - val_dice_metric: 0.5695 - val_jaccard_metric: 0.4750 - val_sensitivity_metric: 0.5813 - val_specificity_metric: 0.5813
# Epoch 11/100
# 22/22 [==============================] - 30s 1s/step - loss: -0.9752 - dice_metric: 0.9842 - jaccard_metric: 0.9693 - sensitivity_metric: 0.9844 - specificity_metric: 0.9844 - val_loss: -0.4483 - val_dice_metric: 0.6724 - val_jaccard_metric: 0.5626 - val_sensitivity_metric: 0.6552 - val_specificity_metric: 0.6552
# Epoch 12/100
# 22/22 [==============================] - 28s 1s/step - loss: -0.9799 - dice_metric: 0.9874 - jaccard_metric: 0.9753 - sensitivity_metric: 0.9873 - specificity_metric: 0.9873 - val_loss: -0.5363 - val_dice_metric: 0.7189 - val_jaccard_metric: 0.6102 - val_sensitivity_metric: 0.6953 - val_specificity_metric: 0.6953
# Epoch 13/100
# 22/22 [==============================] - 29s 1s/step - loss: -0.9804 - dice_metric: 0.9875 - jaccard_metric: 0.9755 - sensitivity_metric: 0.9876 - specificity_metric: 0.9876 - val_loss: -0.5143 - val_dice_metric: 0.7070 - val_jaccard_metric: 0.5991 - val_sensitivity_metric: 0.6862 - val_specificity_metric: 0.6862
# Epoch 14/100
# 22/22 [==============================] - 28s 1s/step - loss: -0.9813 - dice_metric: 0.9881 - jaccard_metric: 0.9767 - sensitivity_metric: 0.9884 - specificity_metric: 0.9884 - val_loss: -0.6585 - val_dice_metric: 0.7971 - val_jaccard_metric: 0.6966 - val_sensitivity_metric: 0.7666 - val_specificity_metric: 0.7666
# Epoch 15/100
# 22/22 [==============================] - 29s 1s/step - loss: -0.9824 - dice_metric: 0.9890 - jaccard_metric: 0.9784 - sensitivity_metric: 0.9892 - specificity_metric: 0.9892 - val_loss: -0.7799 - val_dice_metric: 0.8669 - val_jaccard_metric: 0.7848 - val_sensitivity_metric: 0.8384 - val_specificity_metric: 0.8384
# Epoch 16/100
# 22/22 [==============================] - 30s 1s/step - loss: -0.9832 - dice_metric: 0.9894 - jaccard_metric: 0.9792 - sensitivity_metric: 0.9898 - specificity_metric: 0.9898 - val_loss: -0.8004 - val_dice_metric: 0.8782 - val_jaccard_metric: 0.7990 - val_sensitivity_metric: 0.8496 - val_specificity_metric: 0.8496
# Epoch 17/100
# 22/22 [==============================] - 28s 1s/step - loss: -0.9837 - dice_metric: 0.9897 - jaccard_metric: 0.9798 - sensitivity_metric: 0.9898 - specificity_metric: 0.9898 - val_loss: -0.8262 - val_dice_metric: 0.8962 - val_jaccard_metric: 0.8248 - val_sensitivity_metric: 0.8696 - val_specificity_metric: 0.8696
# Epoch 18/100
# 22/22 [==============================] - 29s 1s/step - loss: -0.9843 - dice_metric: 0.9901 - jaccard_metric: 0.9806 - sensitivity_metric: 0.9903 - specificity_metric: 0.9903 - val_loss: -0.9322 - val_dice_metric: 0.9577 - val_jaccard_metric: 0.9211 - val_sensitivity_metric: 0.9482 - val_specificity_metric: 0.9482
# Epoch 19/100
# 22/22 [==============================] - 30s 1s/step - loss: -0.9842 - dice_metric: 0.9900 - jaccard_metric: 0.9803 - sensitivity_metric: 0.9901 - specificity_metric: 0.9901 - val_loss: -0.9285 - val_dice_metric: 0.9577 - val_jaccard_metric: 0.9211 - val_sensitivity_metric: 0.9462 - val_specificity_metric: 0.9462
# Epoch 20/100
# 22/22 [==============================] - 28s 1s/step - loss: -0.9846 - dice_metric: 0.9903 - jaccard_metric: 0.9809 - sensitivity_metric: 0.9907 - specificity_metric: 0.9907 - val_loss: -0.9416 - val_dice_metric: 0.9651 - val_jaccard_metric: 0.9342 - val_sensitivity_metric: 0.9565 - val_specificity_metric: 0.9565
# Epoch 21/100
# 22/22 [==============================] - 29s 1s/step - loss: -0.9855 - dice_metric: 0.9909 - jaccard_metric: 0.9821 - sensitivity_metric: 0.9910 - specificity_metric: 0.9910 - val_loss: -0.9507 - val_dice_metric: 0.9709 - val_jaccard_metric: 0.9446 - val_sensitivity_metric: 0.9656 - val_specificity_metric: 0.9656
# Epoch 22/100
# 22/22 [==============================] - 28s 1s/step - loss: -0.9862 - dice_metric: 0.9913 - jaccard_metric: 0.9829 - sensitivity_metric: 0.9915 - specificity_metric: 0.9915 - val_loss: -0.9648 - val_dice_metric: 0.9795 - val_jaccard_metric: 0.9603 - val_sensitivity_metric: 0.9778 - val_specificity_metric: 0.9778
# Epoch 23/100
# 22/22 [==============================] - 29s 1s/step - loss: -0.9862 - dice_metric: 0.9914 - jaccard_metric: 0.9829 - sensitivity_metric: 0.9914 - specificity_metric: 0.9914 - val_loss: -0.9645 - val_dice_metric: 0.9791 - val_jaccard_metric: 0.9597 - val_sensitivity_metric: 0.9767 - val_specificity_metric: 0.9767
# Epoch 24/100
# 22/22 [==============================] - 29s 1s/step - loss: -0.9864 - dice_metric: 0.9915 - jaccard_metric: 0.9831 - sensitivity_metric: 0.9915 - specificity_metric: 0.9915 - val_loss: -0.9689 - val_dice_metric: 0.9813 - val_jaccard_metric: 0.9638 - val_sensitivity_metric: 0.9789 - val_specificity_metric: 0.9789
# Epoch 25/100
# 22/22 [==============================] - 29s 1s/step - loss: -0.9867 - dice_metric: 0.9916 - jaccard_metric: 0.9835 - sensitivity_metric: 0.9918 - specificity_metric: 0.9918 - val_loss: -0.9691 - val_dice_metric: 0.9815 - val_jaccard_metric: 0.9641 - val_sensitivity_metric: 0.9776 - val_specificity_metric: 0.9776
# Epoch 26/100
# 22/22 [==============================] - 31s 1s/step - loss: -0.9867 - dice_metric: 0.9916 - jaccard_metric: 0.9834 - sensitivity_metric: 0.9918 - specificity_metric: 0.9918 - val_loss: -0.9697 - val_dice_metric: 0.9816 - val_jaccard_metric: 0.9643 - val_sensitivity_metric: 0.9782 - val_specificity_metric: 0.9782
# Epoch 27/100
# 22/22 [==============================] - 29s 1s/step - loss: -0.9861 - dice_metric: 0.9913 - jaccard_metric: 0.9829 - sensitivity_metric: 0.9914 - specificity_metric: 0.9914 - val_loss: -0.9687 - val_dice_metric: 0.9812 - val_jaccard_metric: 0.9635 - val_sensitivity_metric: 0.9789 - val_specificity_metric: 0.9789
# Epoch 28/100
# 22/22 [==============================] - 30s 1s/step - loss: -0.9870 - dice_metric: 0.9918 - jaccard_metric: 0.9838 - sensitivity_metric: 0.9918 - specificity_metric: 0.9918 - val_loss: -0.9700 - val_dice_metric: 0.9819 - val_jaccard_metric: 0.9649 - val_sensitivity_metric: 0.9790 - val_specificity_metric: 0.9790
# Epoch 29/100
# 22/22 [==============================] - 28s 1s/step - loss: -0.9870 - dice_metric: 0.9918 - jaccard_metric: 0.9838 - sensitivity_metric: 0.9917 - specificity_metric: 0.9917 - val_loss: -0.9730 - val_dice_metric: 0.9836 - val_jaccard_metric: 0.9681 - val_sensitivity_metric: 0.9845 - val_specificity_metric: 0.9845
# Epoch 30/100
# 22/22 [==============================] - 30s 1s/step - loss: -0.9866 - dice_metric: 0.9915 - jaccard_metric: 0.9832 - sensitivity_metric: 0.9917 - specificity_metric: 0.9917 - val_loss: -0.9709 - val_dice_metric: 0.9818 - val_jaccard_metric: 0.9646 - val_sensitivity_metric: 0.9825 - val_specificity_metric: 0.9825
# Epoch 31/100
# 22/22 [==============================] - 30s 1s/step - loss: -0.9868 - dice_metric: 0.9917 - jaccard_metric: 0.9835 - sensitivity_metric: 0.9920 - specificity_metric: 0.9920 - val_loss: -0.9702 - val_dice_metric: 0.9818 - val_jaccard_metric: 0.9647 - val_sensitivity_metric: 0.9784 - val_specificity_metric: 0.9784
# Epoch 32/100
# 22/22 [==============================] - 29s 1s/step - loss: -0.9871 - dice_metric: 0.9919 - jaccard_metric: 0.9840 - sensitivity_metric: 0.9920 - specificity_metric: 0.9920 - val_loss: -0.9707 - val_dice_metric: 0.9819 - val_jaccard_metric: 0.9649 - val_sensitivity_metric: 0.9819 - val_specificity_metric: 0.9819
# Epoch 33/100
# 22/22 [==============================] - 29s 1s/step - loss: -0.9875 - dice_metric: 0.9922 - jaccard_metric: 0.9845 - sensitivity_metric: 0.9921 - specificity_metric: 0.9921 - val_loss: -0.9744 - val_dice_metric: 0.9842 - val_jaccard_metric: 0.9693 - val_sensitivity_metric: 0.9824 - val_specificity_metric: 0.9824
# Epoch 34/100
# 22/22 [==============================] - 29s 1s/step - loss: -0.9879 - dice_metric: 0.9924 - jaccard_metric: 0.9849 - sensitivity_metric: 0.9925 - specificity_metric: 0.9925 - val_loss: -0.9732 - val_dice_metric: 0.9834 - val_jaccard_metric: 0.9678 - val_sensitivity_metric: 0.9804 - val_specificity_metric: 0.9804
# Epoch 35/100
# 22/22 [==============================] - 30s 1s/step - loss: -0.9871 - dice_metric: 0.9918 - jaccard_metric: 0.9838 - sensitivity_metric: 0.9919 - specificity_metric: 0.9919 - val_loss: -0.9648 - val_dice_metric: 0.9786 - val_jaccard_metric: 0.9589 - val_sensitivity_metric: 0.9756 - val_specificity_metric: 0.9756
# Epoch 36/100
# 22/22 [==============================] - 29s 1s/step - loss: -0.9877 - dice_metric: 0.9922 - jaccard_metric: 0.9846 - sensitivity_metric: 0.9923 - specificity_metric: 0.9923 - val_loss: -0.9732 - val_dice_metric: 0.9834 - val_jaccard_metric: 0.9678 - val_sensitivity_metric: 0.9812 - val_specificity_metric: 0.9812
# Epoch 37/100
# 22/22 [==============================] - 29s 1s/step - loss: -0.9883 - dice_metric: 0.9926 - jaccard_metric: 0.9854 - sensitivity_metric: 0.9928 - specificity_metric: 0.9928 - val_loss: -0.9745 - val_dice_metric: 0.9842 - val_jaccard_metric: 0.9693 - val_sensitivity_metric: 0.9817 - val_specificity_metric: 0.9817
# Epoch 38/100
# 22/22 [==============================] - 29s 1s/step - loss: -0.9884 - dice_metric: 0.9927 - jaccard_metric: 0.9855 - sensitivity_metric: 0.9928 - specificity_metric: 0.9928 - val_loss: -0.9749 - val_dice_metric: 0.9845 - val_jaccard_metric: 0.9697 - val_sensitivity_metric: 0.9816 - val_specificity_metric: 0.9816
# Epoch 39/100
# 22/22 [==============================] - 30s 1s/step - loss: -0.9881 - dice_metric: 0.9925 - jaccard_metric: 0.9852 - sensitivity_metric: 0.9926 - specificity_metric: 0.9926 - val_loss: -0.9744 - val_dice_metric: 0.9843 - val_jaccard_metric: 0.9695 - val_sensitivity_metric: 0.9834 - val_specificity_metric: 0.9834
# Epoch 40/100
# 22/22 [==============================] - 30s 1s/step - loss: -0.9878 - dice_metric: 0.9923 - jaccard_metric: 0.9847 - sensitivity_metric: 0.9925 - specificity_metric: 0.9925 - val_loss: -0.9734 - val_dice_metric: 0.9837 - val_jaccard_metric: 0.9684 - val_sensitivity_metric: 0.9839 - val_specificity_metric: 0.9839
# Epoch 41/100
# 22/22 [==============================] - 29s 1s/step - loss: -0.9881 - dice_metric: 0.9925 - jaccard_metric: 0.9851 - sensitivity_metric: 0.9925 - specificity_metric: 0.9925 - val_loss: -0.9732 - val_dice_metric: 0.9839 - val_jaccard_metric: 0.9688 - val_sensitivity_metric: 0.9840 - val_specificity_metric: 0.9840
# Epoch 42/100
# 22/22 [==============================] - 30s 1s/step - loss: -0.9881 - dice_metric: 0.9925 - jaccard_metric: 0.9851 - sensitivity_metric: 0.9926 - specificity_metric: 0.9926 - val_loss: -0.9768 - val_dice_metric: 0.9860 - val_jaccard_metric: 0.9728 - val_sensitivity_metric: 0.9862 - val_specificity_metric: 0.9862
# Epoch 43/100
# 22/22 [==============================] - 29s 1s/step - loss: -0.9874 - dice_metric: 0.9921 - jaccard_metric: 0.9844 - sensitivity_metric: 0.9921 - specificity_metric: 0.9921 - val_loss: -0.9683 - val_dice_metric: 0.9803 - val_jaccard_metric: 0.9619 - val_sensitivity_metric: 0.9754 - val_specificity_metric: 0.9754
# Epoch 44/100
# 22/22 [==============================] - 30s 1s/step - loss: -0.9862 - dice_metric: 0.9913 - jaccard_metric: 0.9828 - sensitivity_metric: 0.9916 - specificity_metric: 0.9916 - val_loss: -0.9691 - val_dice_metric: 0.9813 - val_jaccard_metric: 0.9640 - val_sensitivity_metric: 0.9784 - val_specificity_metric: 0.9784
# Epoch 45/100
# 22/22 [==============================] - 30s 1s/step - loss: -0.9878 - dice_metric: 0.9923 - jaccard_metric: 0.9847 - sensitivity_metric: 0.9925 - specificity_metric: 0.9925 - val_loss: -0.9720 - val_dice_metric: 0.9833 - val_jaccard_metric: 0.9676 - val_sensitivity_metric: 0.9803 - val_specificity_metric: 0.9803
# Epoch 46/100
# 22/22 [==============================] - 30s 1s/step - loss: -0.9862 - dice_metric: 0.9915 - jaccard_metric: 0.9839 - sensitivity_metric: 0.9919 - specificity_metric: 0.9919 - val_loss: -0.9534 - val_dice_metric: 0.9728 - val_jaccard_metric: 0.9488 - val_sensitivity_metric: 0.9676 - val_specificity_metric: 0.9676
# Epoch 47/100
# 22/22 [==============================] - 30s 1s/step - loss: -0.9876 - dice_metric: 0.9921 - jaccard_metric: 0.9844 - sensitivity_metric: 0.9921 - specificity_metric: 0.9921 - val_loss: -0.9717 - val_dice_metric: 0.9831 - val_jaccard_metric: 0.9673 - val_sensitivity_metric: 0.9803 - val_specificity_metric: 0.9803
# Epoch 48/100
# 22/22 [==============================] - 30s 1s/step - loss: -0.9881 - dice_metric: 0.9925 - jaccard_metric: 0.9852 - sensitivity_metric: 0.9925 - specificity_metric: 0.9925 - val_loss: -0.9655 - val_dice_metric: 0.9774 - val_jaccard_metric: 0.9568 - val_sensitivity_metric: 0.9756 - val_specificity_metric: 0.9756
# Epoch 49/100
# 22/22 [==============================] - 29s 1s/step - loss: -0.9872 - dice_metric: 0.9920 - jaccard_metric: 0.9842 - sensitivity_metric: 0.9922 - specificity_metric: 0.9922 - val_loss: -0.9758 - val_dice_metric: 0.9854 - val_jaccard_metric: 0.9716 - val_sensitivity_metric: 0.9854 - val_specificity_metric: 0.9854
# Epoch 50/100
# 22/22 [==============================] - 28s 1s/step - loss: -0.9883 - dice_metric: 0.9927 - jaccard_metric: 0.9855 - sensitivity_metric: 0.9928 - specificity_metric: 0.9928 - val_loss: -0.9739 - val_dice_metric: 0.9822 - val_jaccard_metric: 0.9657 - val_sensitivity_metric: 0.9794 - val_specificity_metric: 0.9794
# Learning rate changed to 1e-05 at epoch 50
# Epoch 51/100
# 22/22 [==============================] - 29s 1s/step - loss: -0.9881 - dice_metric: 0.9925 - jaccard_metric: 0.9853 - sensitivity_metric: 0.9924 - specificity_metric: 0.9924 - val_loss: -0.9790 - val_dice_metric: 0.9870 - val_jaccard_metric: 0.9746 - val_sensitivity_metric: 0.9859 - val_specificity_metric: 0.9859
# Epoch 52/100
# 22/22 [==============================] - 30s 1s/step - loss: -0.9892 - dice_metric: 0.9932 - jaccard_metric: 0.9864 - sensitivity_metric: 0.9934 - specificity_metric: 0.9934 - val_loss: -0.9792 - val_dice_metric: 0.9869 - val_jaccard_metric: 0.9744 - val_sensitivity_metric: 0.9859 - val_specificity_metric: 0.9859
# Epoch 53/100
# 22/22 [==============================] - 28s 1s/step - loss: -0.9891 - dice_metric: 0.9931 - jaccard_metric: 0.9864 - sensitivity_metric: 0.9932 - specificity_metric: 0.9932 - val_loss: -0.9794 - val_dice_metric: 0.9872 - val_jaccard_metric: 0.9750 - val_sensitivity_metric: 0.9860 - val_specificity_metric: 0.9860
# Epoch 54/100
# 22/22 [==============================] - 31s 1s/step - loss: -0.9894 - dice_metric: 0.9933 - jaccard_metric: 0.9867 - sensitivity_metric: 0.9934 - specificity_metric: 0.9934 - val_loss: -0.9797 - val_dice_metric: 0.9875 - val_jaccard_metric: 0.9755 - val_sensitivity_metric: 0.9863 - val_specificity_metric: 0.9863
# Epoch 55/100
# 22/22 [==============================] - 30s 1s/step - loss: -0.9894 - dice_metric: 0.9933 - jaccard_metric: 0.9868 - sensitivity_metric: 0.9934 - specificity_metric: 0.9934 - val_loss: -0.9797 - val_dice_metric: 0.9873 - val_jaccard_metric: 0.9753 - val_sensitivity_metric: 0.9860 - val_specificity_metric: 0.9860
# Epoch 56/100
# 22/22 [==============================] - 29s 1s/step - loss: -0.9899 - dice_metric: 0.9936 - jaccard_metric: 0.9874 - sensitivity_metric: 0.9937 - specificity_metric: 0.9937 - val_loss: -0.9798 - val_dice_metric: 0.9874 - val_jaccard_metric: 0.9754 - val_sensitivity_metric: 0.9862 - val_specificity_metric: 0.9862
# Epoch 57/100
# 22/22 [==============================] - 30s 1s/step - loss: -0.9897 - dice_metric: 0.9935 - jaccard_metric: 0.9871 - sensitivity_metric: 0.9936 - specificity_metric: 0.9936 - val_loss: -0.9800 - val_dice_metric: 0.9876 - val_jaccard_metric: 0.9757 - val_sensitivity_metric: 0.9864 - val_specificity_metric: 0.9864
# Epoch 58/100
# 22/22 [==============================] - 29s 1s/step - loss: -0.9899 - dice_metric: 0.9936 - jaccard_metric: 0.9873 - sensitivity_metric: 0.9937 - specificity_metric: 0.9937 - val_loss: -0.9801 - val_dice_metric: 0.9877 - val_jaccard_metric: 0.9759 - val_sensitivity_metric: 0.9869 - val_specificity_metric: 0.9869
# Epoch 59/100
# 22/22 [==============================] - 30s 1s/step - loss: -0.9895 - dice_metric: 0.9934 - jaccard_metric: 0.9869 - sensitivity_metric: 0.9934 - specificity_metric: 0.9934 - val_loss: -0.9802 - val_dice_metric: 0.9877 - val_jaccard_metric: 0.9759 - val_sensitivity_metric: 0.9871 - val_specificity_metric: 0.9871
# Epoch 60/100
# 22/22 [==============================] - 30s 1s/step - loss: -0.9900 - dice_metric: 0.9937 - jaccard_metric: 0.9874 - sensitivity_metric: 0.9938 - specificity_metric: 0.9938 - val_loss: -0.9797 - val_dice_metric: 0.9871 - val_jaccard_metric: 0.9748 - val_sensitivity_metric: 0.9861 - val_specificity_metric: 0.9861
# Epoch 61/100
# 22/22 [==============================] - 29s 1s/step - loss: -0.9901 - dice_metric: 0.9937 - jaccard_metric: 0.9876 - sensitivity_metric: 0.9938 - specificity_metric: 0.9938 - val_loss: -0.9800 - val_dice_metric: 0.9874 - val_jaccard_metric: 0.9754 - val_sensitivity_metric: 0.9865 - val_specificity_metric: 0.9865
# Epoch 62/100
# 22/22 [==============================] - 29s 1s/step - loss: -0.9901 - dice_metric: 0.9937 - jaccard_metric: 0.9876 - sensitivity_metric: 0.9938 - specificity_metric: 0.9938 - val_loss: -0.9797 - val_dice_metric: 0.9872 - val_jaccard_metric: 0.9749 - val_sensitivity_metric: 0.9861 - val_specificity_metric: 0.9861
# Epoch 63/100
# 22/22 [==============================] - 29s 1s/step - loss: -0.9899 - dice_metric: 0.9936 - jaccard_metric: 0.9874 - sensitivity_metric: 0.9936 - specificity_metric: 0.9936 - val_loss: -0.9795 - val_dice_metric: 0.9868 - val_jaccard_metric: 0.9743 - val_sensitivity_metric: 0.9859 - val_specificity_metric: 0.9859
# Epoch 64/100
# 22/22 [==============================] - 28s 1s/step - loss: -0.9901 - dice_metric: 0.9938 - jaccard_metric: 0.9876 - sensitivity_metric: 0.9939 - specificity_metric: 0.9939 - val_loss: -0.9793 - val_dice_metric: 0.9867 - val_jaccard_metric: 0.9740 - val_sensitivity_metric: 0.9854 - val_specificity_metric: 0.9854
# Epoch 65/100
# 22/22 [==============================] - 28s 1s/step - loss: -0.9901 - dice_metric: 0.9938 - jaccard_metric: 0.9876 - sensitivity_metric: 0.9938 - specificity_metric: 0.9938 - val_loss: -0.9793 - val_dice_metric: 0.9867 - val_jaccard_metric: 0.9740 - val_sensitivity_metric: 0.9856 - val_specificity_metric: 0.9856
# Epoch 66/100
# 22/22 [==============================] - 30s 1s/step - loss: -0.9904 - dice_metric: 0.9939 - jaccard_metric: 0.9880 - sensitivity_metric: 0.9939 - specificity_metric: 0.9939 - val_loss: -0.9789 - val_dice_metric: 0.9860 - val_jaccard_metric: 0.9728 - val_sensitivity_metric: 0.9848 - val_specificity_metric: 0.9848
# Epoch 67/100
# 22/22 [==============================] - 30s 1s/step - loss: -0.9899 - dice_metric: 0.9937 - jaccard_metric: 0.9875 - sensitivity_metric: 0.9937 - specificity_metric: 0.9937 - val_loss: -0.9790 - val_dice_metric: 0.9864 - val_jaccard_metric: 0.9735 - val_sensitivity_metric: 0.9854 - val_specificity_metric: 0.9854
# Epoch 68/100
# 22/22 [==============================] - 29s 1s/step - loss: -0.9902 - dice_metric: 0.9938 - jaccard_metric: 0.9877 - sensitivity_metric: 0.9939 - specificity_metric: 0.9939 - val_loss: -0.9797 - val_dice_metric: 0.9872 - val_jaccard_metric: 0.9750 - val_sensitivity_metric: 0.9866 - val_specificity_metric: 0.9866
# Epoch 69/100
# 22/22 [==============================] - 29s 1s/step - loss: -0.9903 - dice_metric: 0.9939 - jaccard_metric: 0.9879 - sensitivity_metric: 0.9939 - specificity_metric: 0.9939 - val_loss: -0.9798 - val_dice_metric: 0.9872 - val_jaccard_metric: 0.9751 - val_sensitivity_metric: 0.9865 - val_specificity_metric: 0.9865
# Epoch 70/100
# 22/22 [==============================] - 29s 1s/step - loss: -0.9903 - dice_metric: 0.9939 - jaccard_metric: 0.9878 - sensitivity_metric: 0.9939 - specificity_metric: 0.9939 - val_loss: -0.9801 - val_dice_metric: 0.9875 - val_jaccard_metric: 0.9755 - val_sensitivity_metric: 0.9868 - val_specificity_metric: 0.9868
# Epoch 71/100
# 22/22 [==============================] - 29s 1s/step - loss: -0.9905 - dice_metric: 0.9940 - jaccard_metric: 0.9881 - sensitivity_metric: 0.9941 - specificity_metric: 0.9941 - val_loss: -0.9801 - val_dice_metric: 0.9875 - val_jaccard_metric: 0.9755 - val_sensitivity_metric: 0.9868 - val_specificity_metric: 0.9868
# Epoch 72/100
# 22/22 [==============================] - 29s 1s/step - loss: -0.9901 - dice_metric: 0.9935 - jaccard_metric: 0.9872 - sensitivity_metric: 0.9934 - specificity_metric: 0.9934 - val_loss: -0.9801 - val_dice_metric: 0.9873 - val_jaccard_metric: 0.9751 - val_sensitivity_metric: 0.9865 - val_specificity_metric: 0.9865
# Epoch 73/100
# 22/22 [==============================] - 30s 1s/step - loss: -0.9904 - dice_metric: 0.9939 - jaccard_metric: 0.9880 - sensitivity_metric: 0.9940 - specificity_metric: 0.9940 - val_loss: -0.9809 - val_dice_metric: 0.9879 - val_jaccard_metric: 0.9764 - val_sensitivity_metric: 0.9872 - val_specificity_metric: 0.9872
# Epoch 74/100
# 22/22 [==============================] - 30s 1s/step - loss: -0.9905 - dice_metric: 0.9940 - jaccard_metric: 0.9881 - sensitivity_metric: 0.9940 - specificity_metric: 0.9940 - val_loss: -0.9807 - val_dice_metric: 0.9878 - val_jaccard_metric: 0.9760 - val_sensitivity_metric: 0.9870 - val_specificity_metric: 0.9870
# Epoch 75/100
# 22/22 [==============================] - 30s 1s/step - loss: -0.9903 - dice_metric: 0.9939 - jaccard_metric: 0.9879 - sensitivity_metric: 0.9940 - specificity_metric: 0.9940 - val_loss: -0.9806 - val_dice_metric: 0.9876 - val_jaccard_metric: 0.9758 - val_sensitivity_metric: 0.9868 - val_specificity_metric: 0.9868
# Epoch 76/100
# 22/22 [==============================] - 30s 1s/step - loss: -0.9906 - dice_metric: 0.9941 - jaccard_metric: 0.9882 - sensitivity_metric: 0.9942 - specificity_metric: 0.9942 - val_loss: -0.9805 - val_dice_metric: 0.9877 - val_jaccard_metric: 0.9759 - val_sensitivity_metric: 0.9869 - val_specificity_metric: 0.9869
# Epoch 77/100
# 22/22 [==============================] - 29s 1s/step - loss: -0.9905 - dice_metric: 0.9940 - jaccard_metric: 0.9881 - sensitivity_metric: 0.9940 - specificity_metric: 0.9940 - val_loss: -0.9806 - val_dice_metric: 0.9877 - val_jaccard_metric: 0.9759 - val_sensitivity_metric: 0.9870 - val_specificity_metric: 0.9870
# Epoch 78/100
# 22/22 [==============================] - 29s 1s/step - loss: -0.9903 - dice_metric: 0.9939 - jaccard_metric: 0.9878 - sensitivity_metric: 0.9939 - specificity_metric: 0.9939 - val_loss: -0.9805 - val_dice_metric: 0.9878 - val_jaccard_metric: 0.9761 - val_sensitivity_metric: 0.9873 - val_specificity_metric: 0.9873
# Epoch 79/100
# 22/22 [==============================] - 29s 1s/step - loss: -0.9907 - dice_metric: 0.9941 - jaccard_metric: 0.9883 - sensitivity_metric: 0.9942 - specificity_metric: 0.9942 - val_loss: -0.9805 - val_dice_metric: 0.9877 - val_jaccard_metric: 0.9759 - val_sensitivity_metric: 0.9869 - val_specificity_metric: 0.9869
# Epoch 80/100
# 22/22 [==============================] - 30s 1s/step - loss: -0.9905 - dice_metric: 0.9940 - jaccard_metric: 0.9881 - sensitivity_metric: 0.9941 - specificity_metric: 0.9941 - val_loss: -0.9803 - val_dice_metric: 0.9874 - val_jaccard_metric: 0.9755 - val_sensitivity_metric: 0.9865 - val_specificity_metric: 0.9865
# Epoch 81/100
# 22/22 [==============================] - 30s 1s/step - loss: -0.9907 - dice_metric: 0.9941 - jaccard_metric: 0.9884 - sensitivity_metric: 0.9942 - specificity_metric: 0.9942 - val_loss: -0.9804 - val_dice_metric: 0.9875 - val_jaccard_metric: 0.9755 - val_sensitivity_metric: 0.9865 - val_specificity_metric: 0.9865
# Epoch 82/100
# 22/22 [==============================] - 30s 1s/step - loss: -0.9907 - dice_metric: 0.9942 - jaccard_metric: 0.9884 - sensitivity_metric: 0.9942 - specificity_metric: 0.9942 - val_loss: -0.9805 - val_dice_metric: 0.9877 - val_jaccard_metric: 0.9758 - val_sensitivity_metric: 0.9868 - val_specificity_metric: 0.9868
# Epoch 83/100
# 22/22 [==============================] - 29s 1s/step - loss: -0.9907 - dice_metric: 0.9942 - jaccard_metric: 0.9884 - sensitivity_metric: 0.9942 - specificity_metric: 0.9942 - val_loss: -0.9805 - val_dice_metric: 0.9876 - val_jaccard_metric: 0.9758 - val_sensitivity_metric: 0.9868 - val_specificity_metric: 0.9868
# Epoch 84/100
# 22/22 [==============================] - 29s 1s/step - loss: -0.9909 - dice_metric: 0.9943 - jaccard_metric: 0.9886 - sensitivity_metric: 0.9944 - specificity_metric: 0.9944 - val_loss: -0.9804 - val_dice_metric: 0.9876 - val_jaccard_metric: 0.9756 - val_sensitivity_metric: 0.9867 - val_specificity_metric: 0.9867
# Epoch 85/100
# 22/22 [==============================] - 29s 1s/step - loss: -0.9907 - dice_metric: 0.9941 - jaccard_metric: 0.9884 - sensitivity_metric: 0.9942 - specificity_metric: 0.9942 - val_loss: -0.9804 - val_dice_metric: 0.9876 - val_jaccard_metric: 0.9757 - val_sensitivity_metric: 0.9868 - val_specificity_metric: 0.9868
# Epoch 86/100
# 22/22 [==============================] - 29s 1s/step - loss: -0.9904 - dice_metric: 0.9940 - jaccard_metric: 0.9880 - sensitivity_metric: 0.9940 - specificity_metric: 0.9940 - val_loss: -0.9805 - val_dice_metric: 0.9878 - val_jaccard_metric: 0.9761 - val_sensitivity_metric: 0.9873 - val_specificity_metric: 0.9873
# Epoch 87/100
# 22/22 [==============================] - 29s 1s/step - loss: -0.9908 - dice_metric: 0.9942 - jaccard_metric: 0.9884 - sensitivity_metric: 0.9942 - specificity_metric: 0.9942 - val_loss: -0.9805 - val_dice_metric: 0.9877 - val_jaccard_metric: 0.9759 - val_sensitivity_metric: 0.9872 - val_specificity_metric: 0.9872
# Epoch 88/100
# 22/22 [==============================] - 29s 1s/step - loss: -0.9908 - dice_metric: 0.9942 - jaccard_metric: 0.9885 - sensitivity_metric: 0.9943 - specificity_metric: 0.9943 - val_loss: -0.9805 - val_dice_metric: 0.9877 - val_jaccard_metric: 0.9760 - val_sensitivity_metric: 0.9871 - val_specificity_metric: 0.9871
# Epoch 89/100
# 22/22 [==============================] - 29s 1s/step - loss: -0.9907 - dice_metric: 0.9942 - jaccard_metric: 0.9884 - sensitivity_metric: 0.9942 - specificity_metric: 0.9942 - val_loss: -0.9805 - val_dice_metric: 0.9877 - val_jaccard_metric: 0.9759 - val_sensitivity_metric: 0.9870 - val_specificity_metric: 0.9870
# Epoch 90/100
# 22/22 [==============================] - 31s 1s/step - loss: -0.9910 - dice_metric: 0.9943 - jaccard_metric: 0.9888 - sensitivity_metric: 0.9944 - specificity_metric: 0.9944 - val_loss: -0.9804 - val_dice_metric: 0.9876 - val_jaccard_metric: 0.9757 - val_sensitivity_metric: 0.9868 - val_specificity_metric: 0.9868
# Epoch 91/100
# 22/22 [==============================] - 30s 1s/step - loss: -0.9908 - dice_metric: 0.9942 - jaccard_metric: 0.9885 - sensitivity_metric: 0.9943 - specificity_metric: 0.9943 - val_loss: -0.9804 - val_dice_metric: 0.9876 - val_jaccard_metric: 0.9757 - val_sensitivity_metric: 0.9869 - val_specificity_metric: 0.9869
# Epoch 92/100
# 22/22 [==============================] - 30s 1s/step - loss: -0.9905 - dice_metric: 0.9940 - jaccard_metric: 0.9882 - sensitivity_metric: 0.9940 - specificity_metric: 0.9940 - val_loss: -0.9805 - val_dice_metric: 0.9876 - val_jaccard_metric: 0.9758 - val_sensitivity_metric: 0.9868 - val_specificity_metric: 0.9868
# Epoch 93/100
# 22/22 [==============================] - 29s 1s/step - loss: -0.9906 - dice_metric: 0.9941 - jaccard_metric: 0.9883 - sensitivity_metric: 0.9942 - specificity_metric: 0.9942 - val_loss: -0.9803 - val_dice_metric: 0.9874 - val_jaccard_metric: 0.9754 - val_sensitivity_metric: 0.9864 - val_specificity_metric: 0.9864
# Epoch 94/100
# 22/22 [==============================] - 30s 1s/step - loss: -0.9909 - dice_metric: 0.9943 - jaccard_metric: 0.9886 - sensitivity_metric: 0.9943 - specificity_metric: 0.9943 - val_loss: -0.9805 - val_dice_metric: 0.9875 - val_jaccard_metric: 0.9756 - val_sensitivity_metric: 0.9866 - val_specificity_metric: 0.9866
# Epoch 95/100
# 22/22 [==============================] - 30s 1s/step - loss: -0.9909 - dice_metric: 0.9943 - jaccard_metric: 0.9887 - sensitivity_metric: 0.9943 - specificity_metric: 0.9943 - val_loss: -0.9806 - val_dice_metric: 0.9877 - val_jaccard_metric: 0.9759 - val_sensitivity_metric: 0.9870 - val_specificity_metric: 0.9870
# Epoch 96/100
# 22/22 [==============================] - 30s 1s/step - loss: -0.9910 - dice_metric: 0.9943 - jaccard_metric: 0.9887 - sensitivity_metric: 0.9944 - specificity_metric: 0.9944 - val_loss: -0.9807 - val_dice_metric: 0.9877 - val_jaccard_metric: 0.9760 - val_sensitivity_metric: 0.9869 - val_specificity_metric: 0.9869
# Epoch 97/100
# 22/22 [==============================] - 30s 1s/step - loss: -0.9910 - dice_metric: 0.9944 - jaccard_metric: 0.9888 - sensitivity_metric: 0.9944 - specificity_metric: 0.9944 - val_loss: -0.9807 - val_dice_metric: 0.9878 - val_jaccard_metric: 0.9760 - val_sensitivity_metric: 0.9872 - val_specificity_metric: 0.9872
# Epoch 98/100
# 22/22 [==============================] - 31s 1s/step - loss: -0.9910 - dice_metric: 0.9943 - jaccard_metric: 0.9887 - sensitivity_metric: 0.9944 - specificity_metric: 0.9944 - val_loss: -0.9806 - val_dice_metric: 0.9876 - val_jaccard_metric: 0.9757 - val_sensitivity_metric: 0.9869 - val_specificity_metric: 0.9869
# Epoch 99/100
# 22/22 [==============================] - 31s 1s/step - loss: -0.9912 - dice_metric: 0.9944 - jaccard_metric: 0.9890 - sensitivity_metric: 0.9945 - specificity_metric: 0.9945 - val_loss: -0.9806 - val_dice_metric: 0.9876 - val_jaccard_metric: 0.9758 - val_sensitivity_metric: 0.9870 - val_specificity_metric: 0.9870
# Epoch 100/100
# 22/22 [==============================] - 29s 1s/step - loss: -0.9911 - dice_metric: 0.9944 - jaccard_metric: 0.9889 - sensitivity_metric: 0.9945 - specificity_metric: 0.9945 - val_loss: -0.9805 - val_dice_metric: 0.9875 - val_jaccard_metric: 0.9756 - val_sensitivity_metric: 0.9867 - val_specificity_metric: 0.9867

# %%
model.save(f"{config['Seg_model']}_{config['Activation']}_{config['Dataset']}.keras")

# %% [markdown]
# ### **Guardando modelo en TF_LITE**

# %%
#'model' es tu modelo entrenado
converter = tf.lite.TFLiteConverter.from_keras_model(model)

# Opcional: activar optimizaciones para reducir el tamaño y mejorar la velocidad
converter.optimizations = [tf.lite.Optimize.DEFAULT]

# Realiza la conversión
tflite_model = converter.convert()

# Guarda el modelo TF Lite en un archivo .tflite
tflite_model_file = f"{config['Seg_model']}_{config['Activation']}_{config['Dataset']}.tflite"
with open(tflite_model_file, "wb") as f:
    f.write(tflite_model)
# Out:
# W0000 00:00:1744429244.167587      31 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1744429244.167635      31 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# I0000 00:00:1744429244.583255      31 mlir_graph_optimization_pass.cc:401] MLIR V1 optimization pass is not enabled

# %% [markdown]
# ### **Desempeño del modelo**

# %% [markdown]
# #### **Visualización de las inferencias del modelo Keras**

# %%
def performance_visualization(dataset, model, config):

    # Select a random batch index
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    predictions = model(images[sample:sample+1,...], training=False)

    # Determine the number of columns for the visualization grid

    columns = []
    rows = 3

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)
    
    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-2, :])
    title_ax.set_title("Original masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-2][i].imshow(masks[sample, :, :,classes_list[i]:classes_list[i]+1])

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Predicted masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(tf.where(predictions[0, :, :,classes_list[i]:classes_list[i]+1] >0.5, 1.0, 0.0))

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()
    # Free memory
    del images, predictions, classes_list, masks# Delete large variables
    gc.collect() # Force garbage collection

# %%
performance_visualization(test_dataset, model, config)
# Out:
# Images in the batch: (16, 512, 512, 3), Masks in the batch: (16, 512, 512, 2)
# /tmp/ipykernel_31/3987171811.py:61: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# #### **Rendimiento del modelo para datos de evaluación**

# %%
def performance_measures(model,dataset,config,save_results=True):

    with tf.device('/GPU:0' if tf.config.list_physical_devices('GPU') else '/CPU:0'):
        # Initialize empty lists to store metric results
        dice_results = []
        jaccard_results = []
        sensitivity_results = []
        specificity_results = []

        # Process each batch in the dataset
        for data_batch in dataset:
            images, masks = data_batch

            # Generate model predictions
            y_pred = model(images, training=False)

            # Assume the model's prediction covers all classes
            y_pred_class = y_pred[...,:config['Number of classes']]
            dice_batch = dice_metric(masks, y_pred_class, return_mean=False)
            jaccard_batch = jaccard_metric(masks, y_pred_class, return_mean=False)
            sensitivity_batch = sensitivity_metric(masks, y_pred_class, return_mean=False)
            specificity_batch = specificity_metric(masks, y_pred_class, return_mean=False)
            
            # Store results from the current batch
            dice_results.append(dice_batch.numpy().flatten())
            jaccard_results.append(jaccard_batch.numpy().flatten())
            sensitivity_results.append(sensitivity_batch.numpy().flatten())
            specificity_results.append(specificity_batch.numpy().flatten())

            # Free memory by deleting unnecessary tensors immediately
            del y_pred, y_pred_class, dice_batch, jaccard_batch, sensitivity_batch, specificity_batch, images, masks

        # Convert lists of batches to flat NumPy arrays for analysis
        dice_results = np.concatenate(dice_results)
        jaccard_results = np.concatenate(jaccard_results)
        sensitivity_results = np.concatenate(sensitivity_results)
        specificity_results = np.concatenate(specificity_results)

        # Print performance summaries with 5 decimal places precision
        print("Model's performance metrics:")
        print(f"Dice Coefficient mean: {np.mean(dice_results):.5f}, standard deviation: {np.std(dice_results):.5f}")
        print(f"Jaccard Index mean: {np.mean(jaccard_results):.5f}, standard deviation: {np.std(jaccard_results):.5f}")
        print(f"Sensitivity mean: {np.mean(sensitivity_results):.5f}, standard deviation: {np.std(sensitivity_results):.5f}")
        print(f"Specificity mean: {np.mean(specificity_results):.5f}, standard deviation: {np.std(specificity_results):.5f}")

        # Save results to disk if requested
        if save_results:
            # Check if the directory exists, and if not, create it
            if not os.path.exists('./results'):
                os.makedirs('./results')

            # Generate filenames using the configuration parameters
            filename_base = f"./results/{config['Seg_model']}_{config['Activation']}_{config['Dataset']}"
            np.save(f"{filename_base}_DICE.npy", dice_results)
            np.save(f"{filename_base}_Jaccard.npy", jaccard_results)
            np.save(f"{filename_base}_Sensitivity.npy", sensitivity_results)
            np.save(f"{filename_base}_Specificity.npy", specificity_results)

        # Cleanup intermediate results to free memory
        gc.collect()
        del dice_results, jaccard_results, sensitivity_results, specificity_results
        return [f"{filename_base}_DICE.npy", f"{filename_base}_Jaccard.npy", f"{filename_base}_Sensitivity.npy", f"{filename_base}_Specificity.npy"]

# %%
metrics = performance_measures(model,test_dataset,config,save_results=True)
# Out:
# Model's performance metrics:
# Dice Coefficient mean: 0.98637, standard deviation: 0.01095
# Jaccard Index mean: 0.97333, standard deviation: 0.02096
# Sensitivity mean: 0.98698, standard deviation: 0.01183
# Specificity mean: 0.98698, standard deviation: 0.01183
