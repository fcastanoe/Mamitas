# %% [markdown]
# ### **Descarga e importe de bibliotecas**

# %%
# %%capture
# !pip install git+https://github.com/qubvel/classification_models.git

# %%
import os
os.environ["TF_USE_LEGACY_KERAS"]="1"

# %%
import gc
import re
import glob
import random
import shutil
import zipfile
import numpy as np
from functools import partial
import matplotlib.pyplot as plt

import tensorflow as tf
import tf_keras as keras
import tf_keras.backend as K
from tf_keras.losses import Loss
from tf_keras.layers import Layer
from tf_keras import layers, Model
from tf_keras.optimizers import Adam
from tf_keras.callbacks import Callback
from tf_keras.saving import register_keras_serializable

# ResUNet Model Backbone
from classification_models.tfkeras import Classifiers  # Requires: pip install git+https://github.com/qubvel/classification_models.git

# %% [markdown]
# ### **Configuración del entorno**

# %%
# Set a seed
seed = 42

np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

# %%
# Create a distribution strategy
strategy = tf.distribute.MirroredStrategy()
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# Out:
# Number of devices: 2

# %% [markdown]
# ### **Descarga y cargado de la base de datos de mamitas**

# %% [markdown]
# ##### **Importante definir el número de clases**

# %%
classes = 2 # Son dos clases; 0-Fondo, 1-feet

# %%
# Download histology dataset
classes_ = {2:3}
# !kaggle datasets download fredycastao/Mamitas-Only-Subject/{classes_[classes]} 

os.makedirs('./datasets/Mamitas', exist_ok=True)
with zipfile.ZipFile('./Mamitas-Only-Subject.zip', 'r') as zip_ref: zip_ref.extractall('./datasets/Mamitas')
# !rm -rf ./Mamitas-Only-Subject.zip
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.7.4.2 / client 1.6.17)
# Dataset URL: https://www.kaggle.com/datasets/fredycastao/Mamitas-Only-Subject/versions/3
# License(s): CC-BY-SA-4.0
# Downloading Mamitas-Only-Subject.zip to /kaggle/working
#  87%|█████████████████████████████████▉     | 65.0M/74.7M [00:00<00:00, 146MB/s]
# 100%|███████████████████████████████████████| 74.7M/74.7M [00:00<00:00, 150MB/s]

# %%
config = {"Seg_model":"ResUNet","Activation":"softmax","Input size":(512,512,3),"Image size":(512,512),
          "Dataset":"Mamitas","Dir of dataset":"./datasets/Mamitas","Batch size":32,"Epochs":100,"Number of classes":classes}

# %%
class DataLoader:

    def __init__(self, data_dir, batch_size, image_size, num_classes, partition):

        self.data_dir = data_dir
        self.batch_size = batch_size
        self.image_size = image_size
        self.num_classes = num_classes
        self.partition = partition

    def load_images(self):

        # Create the path for patch images
        images_path_pattern = os.path.join(self.data_dir, self.partition, 'images', '*.png')
        images_files = glob.glob(images_path_pattern)

        # Sort patch files alphanumerically
        def alphanumeric_key(s):
            # Split the string into parts (numbers and text)
            parts = re.split(r'(\d+)', s)
            # Convert numeric parts to integers for proper sorting
            return [int(part) if part.isdigit() else part for part in parts]

        images_files = sorted(images_files, key=alphanumeric_key)

        self.file_sample = []
        for file in images_files:
            name_file = file.split('/')[-1]
            self.file_sample.append(name_file)

        self.num_samples = len(images_files)

        # Print the complete path and the number of found patch images
        print(f"Complete images: {images_path_pattern}")
        print(f"Number of images files found: {len(images_files)}")

        # Create a TensorFlow dataset from the images file paths
        images_ds = tf.data.Dataset.from_tensor_slices(images_files)

        # Map each file path to a processed image
        images_ds = images_ds.map(self.process_images, num_parallel_calls=tf.data.AUTOTUNE)

        return images_ds

    def load_masks(self):

        mask_path_main = os.path.join(self.data_dir, self.partition, 'masks')

        # Check samples in classes
        for class_id in range(self.num_classes):
            mask_path_pattern = os.path.join(mask_path_main, f'class_{class_id}', '*.png')
            found_masks = glob.glob(mask_path_pattern)
            print(f"Original masks path, class {class_id}: {mask_path_pattern}")
            print(f"Number of masks found: {len(found_masks)}")

        masks_path = []
        # Organize ground truth masks by sample and class
        for sample in self.file_sample:
            masks_sample = []
            for class_id in range(self.num_classes):
                masks_sample.append(os.path.join(mask_path_main, f'class_{class_id}', sample))
            masks_path.append(masks_sample)

        # Create dataset from `masks_path` and apply `process_masks` to each set of paths
        masks_ds = tf.data.Dataset.from_tensor_slices(masks_path)
        masks_ds = masks_ds.map(self.process_masks, num_parallel_calls=tf.data.AUTOTUNE)

        return masks_ds

    def process_images(self, file_path):

        img = tf.io.read_file(file_path)  # Read the image file
        img = tf.image.decode_png(img, channels=3)  # Decode PNG image
        img = tf.image.resize(img, self.image_size)  # Resize image
        img = tf.cast(img, tf.float32)  # Convert to float32
        img /= 255.0  # Normalize to [0, 1]
        return img

    def process_masks(self, sample_paths):

        # Decode and process images
        decoded_images = tf.map_fn(
            tf.io.read_file,
            sample_paths,
            dtype=tf.string,
            parallel_iterations=4
        )

        masks = tf.map_fn(
            lambda x: tf.io.decode_png(x, channels=1),
            decoded_images,
            dtype=tf.uint8,
            parallel_iterations=4
        )

        # Resize and normalize
        masks = tf.map_fn(
            lambda x: tf.image.resize(x, size=self.image_size),
            masks,
            dtype=tf.float32
        )

        masks = tf.cast(masks, tf.float32)  # Convert to float32
        masks = masks / 255.0  # Normalize to [0, 1]
        masks = tf.squeeze(masks, axis=-1)  # Remove the last dimension
        masks = tf.transpose(masks, perm=[1, 2, 0])  # Transpose to [height, width, classes]

        return masks

    def get_dataset(self):

        images_ds = self.load_images()
        masks_ds = self.load_masks()
        dataset = tf.data.Dataset.zip((images_ds,masks_ds))

        # Apply batching and prefetching for optimization
        dataset = dataset.batch(self.batch_size)
        dataset = dataset.prefetch(tf.data.AUTOTUNE)

        return dataset

# %%
# Instantiate data loader and load train partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Train')
train_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Mamitas/Train/images/*.png
# Number of images files found: 342
# Original masks path, class 0: ./datasets/Mamitas/Train/masks/class_0/*.png
# Number of masks found: 342
# Original masks path, class 1: ./datasets/Mamitas/Train/masks/class_1/*.png
# Number of masks found: 342

# %%
# Instantiate data loader and load validation partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Valid')
valid_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Mamitas/Valid/images/*.png
# Number of images files found: 37
# Original masks path, class 0: ./datasets/Mamitas/Valid/masks/class_0/*.png
# Number of masks found: 37
# Original masks path, class 1: ./datasets/Mamitas/Valid/masks/class_1/*.png
# Number of masks found: 37

# %%
# Instantiate data loader and load test partition
data_loader = DataLoader(config['Dir of dataset'], config['Batch size'], 
                         config['Image size'], config['Number of classes'],'Test')
test_dataset = data_loader.get_dataset()
# Out:
# Complete images: ./datasets/Mamitas/Test/images/*.png
# Number of images files found: 37
# Original masks path, class 0: ./datasets/Mamitas/Test/masks/class_0/*.png
# Number of masks found: 37
# Original masks path, class 1: ./datasets/Mamitas/Test/masks/class_1/*.png
# Number of masks found: 37

# %% [markdown]
# #### **Visualización de la base de datos de semillas**

# %%
def random_sample_visualization(dataset, num_classes):

    # Select first batch
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    # Determine the number of columns for the visualization grid
    columns = []
    rows = 2

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)

    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Masks of segmentation for different classes",loc='left')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(num_classes,columns):
        num = random.randint(0, num_classes-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(masks[sample, :, :, classes_list[i]:classes_list[i]+1])

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()

    # Free memory
    del images, masks # Delete large variables
    if 'annotators_list' in locals():
        del annotators_list
    if 'classes_list' in locals():
        del classes_list
    gc.collect() # Force garbage collection

# %%
random_sample_visualization(train_dataset, config['Number of classes'])
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 2)
# <ipython-input-13-bf66a0e7f52d>:46: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# ### **Definición y creación del modelo, medidas de rendimiento y función de pérdida**

# %%
ResNet34, preprocess_input = Classifiers.get('resnet34')

# Definition of layers for the neural network structure

DefaultConv2D = partial(layers.Conv2D,
                        kernel_size=3, activation='relu', padding="same")

DefaultPooling = partial(layers.MaxPool2D,
                        pool_size=2)


upsample = partial(layers.UpSampling2D, (2,2))

@register_keras_serializable(package="my_custom_losses")
class DiceCoefficient(Loss):
    def __init__(self, smooth=1., target_class= None, name='DiceCoefficient', **kwargs):
        self.smooth = smooth
        self.target_class = target_class
        super().__init__(name=name,**kwargs)

    def call(self, y_true, y_pred):
        intersection = K.sum(y_true * y_pred, axis=[1,2])
        union = K.sum(y_true,axis=[1,2]) + K.sum(y_pred,axis=[1,2])
        dice_coef = -(2. * intersection + self.smooth) /(union + self.smooth)
        
        if self.target_class != None:
            dice_coef = tf.gather(dice_coef,
                                  self.target_class, axis=1)
        else:
            dice_coef = K.mean(dice_coef,axis=-1)

        return dice_coef

    def get_config(self,):
        base_config = super().get_config()
        return {**base_config, "smooth": self.smooth,
                "target_class":self.target_class}

@register_keras_serializable(package="my_custom_metrics")
def dice_metric(y_true, y_pred, smooth=1e-7, axis=(1, 2), return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis)
    dice = (2. * intersection + smooth) / (union + smooth)

    if return_mean:
        return tf.reduce_mean(dice)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if dice.shape[1] > 1:
            return tf.transpose(dice, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(dice, perm=[1, 0]), axis=0)
            
@register_keras_serializable(package="my_custom_metrics")
def jaccard_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    intersection = tf.reduce_sum(y_true * y_pred, axis=axis)
    union = tf.reduce_sum(y_true, axis=axis) + tf.reduce_sum(y_pred, axis=axis) - intersection
    jaccard = (intersection + smooth) / (union + smooth)
    if return_mean:
        return tf.reduce_mean(jaccard)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if jaccard.shape[1] > 1:
            return tf.transpose(jaccard, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(jaccard, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def sensitivity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_positives = tf.reduce_sum(y_true * y_pred, axis=axis)
    actual_positives = tf.reduce_sum(y_true, axis=axis)
    sensitivity = true_positives / (actual_positives + smooth)
    if return_mean:
        return tf.reduce_mean(sensitivity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if sensitivity.shape[1] > 1:
            return tf.transpose(sensitivity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(sensitivity, perm=[1, 0]), axis=0)

@register_keras_serializable(package="my_custom_metrics")
def specificity_metric(y_true, y_pred, axis=(1, 2), smooth=1e-7, return_mean=True):
    y_true = tf.cast(y_true, tf.float32)
    y_true = tf.where(y_true > 0.5, 1.0, 0.0)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.where(y_pred > 0.5, 1.0, 0.0)
    true_negatives = tf.reduce_sum((1 - y_true) * (1 - y_pred), axis=axis)
    actual_negatives = tf.reduce_sum(1 - y_true, axis=axis)
    specificity = true_negatives / (actual_negatives + tf.keras.backend.epsilon())
    if return_mean:
        return tf.reduce_mean(specificity)
    else:
        # For multi-class segmentation, handle the class dimension correctly
        # The shape of dice is [batch_size, num_classes]
        # Return without squeezing if there are multiple classes
        if specificity.shape[1] > 1:
            return tf.transpose(specificity, perm=[1, 0])  # Shape: [num_classes, batch_size]
        else:
            return tf.squeeze(tf.transpose(specificity, perm=[1, 0]), axis=0)


@register_keras_serializable(package="my_custom_activations")
def sparse_softmax(x):
    
    e_x = tf.exp(x - tf.reduce_max(x, axis=-1, keepdims=True))
    sum_e_x = tf.reduce_sum(e_x, axis=-1, keepdims=True)
    output = e_x / (sum_e_x + keras.backend.epsilon())
    return output

def kernel_initializer(seed):
    
    return tf.keras.initializers.GlorotUniform(seed=seed)


def residual_block(x, filters, kernel_initializer, block_name):
    
    shortcut = x
    x = DefaultConv2D(filters, kernel_initializer=kernel_initializer, name=f'Conv_{block_name}_1')(x)
    x = layers.BatchNormalization(name=f'Batch_{block_name}_1')(x)
    x = DefaultConv2D(filters, kernel_initializer=kernel_initializer, name=f'Conv_{block_name}_2')(x)
    x = layers.BatchNormalization(name=f'Batch_{block_name}_2')(x)
    x = layers.Add(name=f'ResAdd_{block_name}')([shortcut, x])
    x = layers.Activation('relu', name=f'ResAct_{block_name}')(x)
    return x

def UNet(inputs, out_channels, activation):
    
    # Encoder - Downsampling path with increasing filter numbers
    # Each level follows: Conv -> Dropout -> BatchNorm -> Conv -> Dropout -> BatchNorm -> Pooling

    x = layers.BatchNormalization(name='Batch00')(inputs)
    x = DefaultConv2D(8, kernel_initializer=kernel_initializer(34), name='Conv10')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch10')(x)
    x = level_1 = DefaultConv2D(8, kernel_initializer=kernel_initializer(4), name='Conv11')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch11')(x)
    x = DefaultPooling(name='Pool10')(x)  # 128x128 -> 64x64

    x = DefaultConv2D(16, kernel_initializer=kernel_initializer(56), name='Conv20')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch20')(x)
    x = level_2 = DefaultConv2D(16, kernel_initializer=kernel_initializer(32), name='Conv21')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch22')(x)
    x = DefaultPooling(name='Pool20')(x)  # 64x64 -> 32x32

    x = DefaultConv2D(32, kernel_initializer=kernel_initializer(87), name='Conv30')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch30')(x)
    x = level_3 = DefaultConv2D(32, kernel_initializer=kernel_initializer(30), name='Conv31')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch31')(x)
    x = DefaultPooling(name='Pool30')(x)  # 32x32 -> 16x16

    x = DefaultConv2D(64, kernel_initializer=kernel_initializer(79), name='Conv40')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch40')(x)
    x = level_4 = DefaultConv2D(64, kernel_initializer=kernel_initializer(81), name='Conv41')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch41')(x)
    x = DefaultPooling(name='Pool40')(x)  # 16x16 -> 8x8

    # Decoder - Upsampling path with decreasing filter numbers
    # Each level follows: Conv -> Dropout -> BatchNorm -> Conv -> Dropout -> BatchNorm
    x = DefaultConv2D(128, kernel_initializer=kernel_initializer(89), name='Conv50')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch50')(x)
    x = DefaultConv2D(128, kernel_initializer=kernel_initializer(42), name='Conv51')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch51')(x)

    # Upsampling and skip connection with level_4 features
    x = upsample(name='Up60')(x)  # 8x8 -> 16x16
    x = layers.Concatenate(name='Concat60')([level_4, x])
    x = DefaultConv2D(64, kernel_initializer=kernel_initializer(91), name='Conv60')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch60')(x)
    x = DefaultConv2D(64, kernel_initializer=kernel_initializer(47), name='Conv61')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch61')(x)

    # Upsampling and skip connection with level_3 features
    x = upsample(name='Up70')(x)  # 16x16 -> 32x32
    x = layers.Concatenate(name='Concat70')([level_3, x])
    x = DefaultConv2D(32, kernel_initializer=kernel_initializer(21), name='Conv70')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch70')(x)
    x = DefaultConv2D(32, kernel_initializer=kernel_initializer(96), name='Conv71')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch71')(x)

    # Upsampling and skip connection with level_2 features
    x = upsample(name='Up80')(x)  # 32x32 -> 64x64
    x = layers.Concatenate(name='Concat80')([level_2, x])
    x = DefaultConv2D(16, kernel_initializer=kernel_initializer(96), name='Conv80')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch80')(x)
    x = DefaultConv2D(16, kernel_initializer=kernel_initializer(98), name='Conv81')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch81')(x)

    # Upsampling and skip connection with level_1 features
    x = upsample(name='Up90')(x)  # 64x64 -> 128x128
    x = layers.Concatenate(name='Concat90')([level_1, x])
    x = DefaultConv2D(8, kernel_initializer=kernel_initializer(35), name='Conv90')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch90')(x)
    x = DefaultConv2D(8, kernel_initializer=kernel_initializer(7), name='Conv91')(x)
    x = layers.Dropout(0.1)(x)
    x = layers.BatchNormalization(name='Batch91')(x)

    # Final segmentation output with specified activation
    if activation == 'sparse_softmax':
        x = DefaultConv2D(out_channels, kernel_size=(1, 1), activation=sparse_softmax,
                          kernel_initializer=kernel_initializer(42), name='Conv200')(x)
    else:
        x = DefaultConv2D(out_channels, kernel_size=(1, 1), activation=activation,
                          kernel_initializer=kernel_initializer(42), name='Conv200')(x)

    return x


def ResUNet(inputs, input_shape, out_channels,activation):
    
    # Backbone (ResNet34) - Use pre-trained weights from ImageNet
    backbone = ResNet34(
        input_shape=input_shape,
        input_tensor=inputs,
        include_top=False,
        weights='imagenet')

    # Freeze backbone layers except BatchNormalization layers
    # This allows the model to adapt to the new domain while retaining learned features
    for layer in backbone.layers:
        if not isinstance(layer, layers.BatchNormalization):
            layer.trainable = False

    # Extract feature maps from different levels of the ResNet backbone
    level_1 = backbone.layers[5].output   # 128x128x64
    level_2 = backbone.layers[37].output  # 64x64x64
    level_3 = backbone.layers[74].output  # 32x32x128
    level_4 = backbone.layers[129].output # 16x16x256
    x = backbone.layers[157].output       # 8x8x512

    # Decoder - Upsampling path with skip connections to encoder features
    # First upsampling block
    x = upsample(name='Up60')(x)
    x = layers.Concatenate(name='Concat60')([level_4, x])
    x = DefaultConv2D(256, kernel_initializer=kernel_initializer(91) , name='Conv60')(x)
    x = residual_block(x, 256, kernel_initializer(47), '60')  # Apply residual block

    # Second upsampling block
    x = upsample(name='Up70')(x)
    x = layers.Concatenate(name='Concat70')([level_3, x])
    x = DefaultConv2D(128, kernel_initializer=kernel_initializer(21), name='Conv70')(x)
    x = residual_block(x, 128, kernel_initializer(96), '70')  # Apply residual block

    # Third upsampling block
    x = upsample(name='Up80')(x)
    x = layers.Concatenate(name='Concat80')([level_2, x])
    x = DefaultConv2D(64, kernel_initializer=kernel_initializer(96), name='Conv80')(x)
    x = residual_block(x, 64, kernel_initializer(98), '80')  # Apply residual block

    # Fourth upsampling block
    x = upsample(name='Up90')(x)
    x = layers.Concatenate(name='Concat90')([level_1, x])
    x = DefaultConv2D(32, kernel_initializer=kernel_initializer(35), name='Conv90')(x)
    x = residual_block(x, 32, kernel_initializer(7), '90')  # Apply residual block

    # Final upsampling block - connect back to input
    x = upsample(name='Up100')(x)
    x = layers.Concatenate(name='Concat100')([inputs, x])
    x = DefaultConv2D(16, kernel_initializer=kernel_initializer(45), name='Conv100')(x)
    x = residual_block(x, 16, kernel_initializer(7), '100')  # Apply residual block

    # Final segmentation output with specified activation
    if activation == 'sparse_softmax':
        x = DefaultConv2D(out_channels, kernel_size=(1, 1), activation=sparse_softmax,
                          kernel_initializer=kernel_initializer(42), name='Conv200')(x)
    else:
        x = DefaultConv2D(out_channels, kernel_size=(1, 1), activation=activation,
                          kernel_initializer=kernel_initializer(42), name='Conv200')(x)

    return x

def Seg_Model(class_no=2, input_shape=(512, 512, 3), seg_model='ResUNet', activation='softmax'):
    
    # Input layer definition
    image_input = layers.Input(shape=input_shape, name='image_input')

    # Select and build the appropriate segmentation backbone
    if seg_model == 'ResUNet':
        # Use ResNet-based UNet architecture
        seg_rm = ResUNet(image_input, input_shape, out_channels=class_no, activation=activation)
    elif seg_model == 'UNet':
        # Use standard UNet architecture
        seg_rm = UNet(image_input, out_channels=class_no, activation=activation)
    else:
        # Raise error for unsupported model types
        raise ValueError(f"Unsupported segmentation model type: {seg_model}. Supported models are 'ResUNet' and 'UNet'.")

    # Create and return the final model
    return Model(image_input, seg_rm, name=seg_model)

# %%
with strategy.scope():
    model = Seg_Model(class_no=config['Number of classes'],input_shape=config['Input size'], 
                 seg_model=config['Seg_model'], activation=config['Activation'])
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-4),
                  loss=DiceCoefficient(smooth=1e-7, target_class=None if config['Number of classes'] == 3 else 1),
                  metrics=[dice_metric,jaccard_metric,sensitivity_metric,specificity_metric])
# Out:
# Downloading data from https://github.com/qubvel/classification_models/releases/download/0.0.1/resnet34_imagenet_1000_no_top.h5
# 85521592/85521592 [==============================] - 0s 0us/step

# %% [markdown]
# ### **Entrenamiento de la base de datos**

# %%
class CustomLearningRateScheduler(Callback):
    def __init__(self, new_lr, epoch_to_change):
        super(CustomLearningRateScheduler, self).__init__()
        self.new_lr = new_lr
        self.epoch_to_change = epoch_to_change

    def on_epoch_begin(self, epoch, logs=None):
        if epoch == self.epoch_to_change:
            tf.keras.backend.set_value(self.model.optimizer.learning_rate, self.new_lr)
            print(f"Learning rate changed to {self.new_lr} at epoch {epoch}") 

lr_scheduler = CustomLearningRateScheduler(1e-5, 50)
history = model.fit(train_dataset, epochs=config['Epochs'], validation_data=(valid_dataset), callbacks=[lr_scheduler])
# Out:
# Epoch 1/100
# 11/11 [==============================] - 78s 3s/step - loss: -0.3948 - dice_metric: 0.5384 - jaccard_metric: 0.3856 - sensitivity_metric: 0.6511 - specificity_metric: 0.6511 - val_loss: -0.3737 - val_dice_metric: 0.2637 - val_jaccard_metric: 0.1605 - val_sensitivity_metric: 0.5346 - val_specificity_metric: 0.5346
# Epoch 2/100
# 11/11 [==============================] - 13s 1s/step - loss: -0.6006 - dice_metric: 0.7321 - jaccard_metric: 0.5999 - sensitivity_metric: 0.7956 - specificity_metric: 0.7956 - val_loss: -0.1860 - val_dice_metric: 0.4319 - val_jaccard_metric: 0.3816 - val_sensitivity_metric: 0.4998 - val_specificity_metric: 0.4998
# Epoch 3/100
# 11/11 [==============================] - 15s 1s/step - loss: -0.7175 - dice_metric: 0.8161 - jaccard_metric: 0.7068 - sensitivity_metric: 0.8458 - specificity_metric: 0.8458 - val_loss: -0.2319 - val_dice_metric: 0.4526 - val_jaccard_metric: 0.3892 - val_sensitivity_metric: 0.5030 - val_specificity_metric: 0.5030
# Epoch 4/100
# 11/11 [==============================] - 17s 1s/step - loss: -0.7867 - dice_metric: 0.8627 - jaccard_metric: 0.7711 - sensitivity_metric: 0.8754 - specificity_metric: 0.8754 - val_loss: -0.0107 - val_dice_metric: 0.4320 - val_jaccard_metric: 0.3818 - val_sensitivity_metric: 0.5000 - val_specificity_metric: 0.5000
# Epoch 5/100
# 11/11 [==============================] - 15s 1s/step - loss: -0.8349 - dice_metric: 0.8943 - jaccard_metric: 0.8174 - sensitivity_metric: 0.9017 - specificity_metric: 0.9017 - val_loss: -0.0067 - val_dice_metric: 0.4320 - val_jaccard_metric: 0.3818 - val_sensitivity_metric: 0.5000 - val_specificity_metric: 0.5000
# Epoch 6/100
# 11/11 [==============================] - 18s 2s/step - loss: -0.8697 - dice_metric: 0.9173 - jaccard_metric: 0.8531 - sensitivity_metric: 0.9222 - specificity_metric: 0.9222 - val_loss: -0.0055 - val_dice_metric: 0.4320 - val_jaccard_metric: 0.3818 - val_sensitivity_metric: 0.5000 - val_specificity_metric: 0.5000
# Epoch 7/100
# 11/11 [==============================] - 18s 2s/step - loss: -0.8961 - dice_metric: 0.9342 - jaccard_metric: 0.8804 - sensitivity_metric: 0.9368 - specificity_metric: 0.9368 - val_loss: -0.0040 - val_dice_metric: 0.4320 - val_jaccard_metric: 0.3817 - val_sensitivity_metric: 0.5000 - val_specificity_metric: 0.5000
# Epoch 8/100
# 11/11 [==============================] - 16s 1s/step - loss: -0.9157 - dice_metric: 0.9469 - jaccard_metric: 0.9017 - sensitivity_metric: 0.9465 - specificity_metric: 0.9465 - val_loss: -0.0047 - val_dice_metric: 0.4320 - val_jaccard_metric: 0.3817 - val_sensitivity_metric: 0.4999 - val_specificity_metric: 0.4999
# Epoch 9/100
# 11/11 [==============================] - 18s 2s/step - loss: -0.9237 - dice_metric: 0.9516 - jaccard_metric: 0.9096 - sensitivity_metric: 0.9531 - specificity_metric: 0.9531 - val_loss: -0.0032 - val_dice_metric: 0.4320 - val_jaccard_metric: 0.3817 - val_sensitivity_metric: 0.4999 - val_specificity_metric: 0.4999
# Epoch 10/100
# 11/11 [==============================] - 16s 1s/step - loss: -0.9241 - dice_metric: 0.9523 - jaccard_metric: 0.9108 - sensitivity_metric: 0.9539 - specificity_metric: 0.9539 - val_loss: -0.0632 - val_dice_metric: 0.4448 - val_jaccard_metric: 0.3894 - val_sensitivity_metric: 0.5062 - val_specificity_metric: 0.5062
# Epoch 11/100
# 11/11 [==============================] - 15s 1s/step - loss: -0.9199 - dice_metric: 0.9496 - jaccard_metric: 0.9060 - sensitivity_metric: 0.9498 - specificity_metric: 0.9498 - val_loss: -0.0470 - val_dice_metric: 0.4394 - val_jaccard_metric: 0.3856 - val_sensitivity_metric: 0.5029 - val_specificity_metric: 0.5029
# Epoch 12/100
# 11/11 [==============================] - 17s 1s/step - loss: -0.9396 - dice_metric: 0.9622 - jaccard_metric: 0.9285 - sensitivity_metric: 0.9642 - specificity_metric: 0.9642 - val_loss: -0.0181 - val_dice_metric: 0.4340 - val_jaccard_metric: 0.3827 - val_sensitivity_metric: 0.5006 - val_specificity_metric: 0.5006
# Epoch 13/100
# 11/11 [==============================] - 15s 1s/step - loss: -0.9549 - dice_metric: 0.9719 - jaccard_metric: 0.9461 - sensitivity_metric: 0.9712 - specificity_metric: 0.9712 - val_loss: -0.0521 - val_dice_metric: 0.4411 - val_jaccard_metric: 0.3867 - val_sensitivity_metric: 0.5038 - val_specificity_metric: 0.5038
# Epoch 14/100
# 11/11 [==============================] - 19s 2s/step - loss: -0.9634 - dice_metric: 0.9772 - jaccard_metric: 0.9559 - sensitivity_metric: 0.9770 - specificity_metric: 0.9770 - val_loss: -0.0171 - val_dice_metric: 0.4327 - val_jaccard_metric: 0.3819 - val_sensitivity_metric: 0.4998 - val_specificity_metric: 0.4998
# Epoch 15/100
# 11/11 [==============================] - 16s 1s/step - loss: -0.9690 - dice_metric: 0.9808 - jaccard_metric: 0.9626 - sensitivity_metric: 0.9807 - specificity_metric: 0.9807 - val_loss: -0.0147 - val_dice_metric: 0.4323 - val_jaccard_metric: 0.3817 - val_sensitivity_metric: 0.4998 - val_specificity_metric: 0.4998
# Epoch 16/100
# 11/11 [==============================] - 17s 1s/step - loss: -0.9707 - dice_metric: 0.9819 - jaccard_metric: 0.9648 - sensitivity_metric: 0.9816 - specificity_metric: 0.9816 - val_loss: -0.0214 - val_dice_metric: 0.4359 - val_jaccard_metric: 0.3837 - val_sensitivity_metric: 0.5015 - val_specificity_metric: 0.5015
# Epoch 17/100
# 11/11 [==============================] - 16s 1s/step - loss: -0.9723 - dice_metric: 0.9829 - jaccard_metric: 0.9665 - sensitivity_metric: 0.9825 - specificity_metric: 0.9825 - val_loss: -0.1329 - val_dice_metric: 0.4903 - val_jaccard_metric: 0.4167 - val_sensitivity_metric: 0.5310 - val_specificity_metric: 0.5310
# Epoch 18/100
# 11/11 [==============================] - 18s 2s/step - loss: -0.9704 - dice_metric: 0.9816 - jaccard_metric: 0.9642 - sensitivity_metric: 0.9815 - specificity_metric: 0.9815 - val_loss: -0.0144 - val_dice_metric: 0.4334 - val_jaccard_metric: 0.3824 - val_sensitivity_metric: 0.5005 - val_specificity_metric: 0.5005
# Epoch 19/100
# 11/11 [==============================] - 17s 2s/step - loss: -0.9672 - dice_metric: 0.9796 - jaccard_metric: 0.9604 - sensitivity_metric: 0.9795 - specificity_metric: 0.9795 - val_loss: -0.0036 - val_dice_metric: 0.4320 - val_jaccard_metric: 0.3816 - val_sensitivity_metric: 0.4998 - val_specificity_metric: 0.4998
# Epoch 20/100
# 11/11 [==============================] - 17s 1s/step - loss: -0.9611 - dice_metric: 0.9753 - jaccard_metric: 0.9524 - sensitivity_metric: 0.9777 - specificity_metric: 0.9777 - val_loss: -4.6998e-04 - val_dice_metric: 0.4319 - val_jaccard_metric: 0.3816 - val_sensitivity_metric: 0.4998 - val_specificity_metric: 0.4998
# Epoch 21/100
# 11/11 [==============================] - 16s 1s/step - loss: -0.9518 - dice_metric: 0.9700 - jaccard_metric: 0.9430 - sensitivity_metric: 0.9756 - specificity_metric: 0.9756 - val_loss: -9.5646e-04 - val_dice_metric: 0.4318 - val_jaccard_metric: 0.3814 - val_sensitivity_metric: 0.4995 - val_specificity_metric: 0.4995
# Epoch 22/100
# 11/11 [==============================] - 17s 2s/step - loss: -0.9537 - dice_metric: 0.9714 - jaccard_metric: 0.9454 - sensitivity_metric: 0.9697 - specificity_metric: 0.9697 - val_loss: -0.1860 - val_dice_metric: 0.5283 - val_jaccard_metric: 0.4380 - val_sensitivity_metric: 0.5478 - val_specificity_metric: 0.5478
# Epoch 23/100
# 11/11 [==============================] - 17s 1s/step - loss: -0.9702 - dice_metric: 0.9816 - jaccard_metric: 0.9641 - sensitivity_metric: 0.9793 - specificity_metric: 0.9793 - val_loss: -0.2367 - val_dice_metric: 0.5619 - val_jaccard_metric: 0.4581 - val_sensitivity_metric: 0.5681 - val_specificity_metric: 0.5681
# Epoch 24/100
# 11/11 [==============================] - 15s 1s/step - loss: -0.9766 - dice_metric: 0.9855 - jaccard_metric: 0.9717 - sensitivity_metric: 0.9873 - specificity_metric: 0.9873 - val_loss: -0.0890 - val_dice_metric: 0.4760 - val_jaccard_metric: 0.4071 - val_sensitivity_metric: 0.5209 - val_specificity_metric: 0.5209
# Epoch 25/100
# 11/11 [==============================] - 18s 2s/step - loss: -0.9800 - dice_metric: 0.9876 - jaccard_metric: 0.9756 - sensitivity_metric: 0.9882 - specificity_metric: 0.9882 - val_loss: -0.2003 - val_dice_metric: 0.5509 - val_jaccard_metric: 0.4543 - val_sensitivity_metric: 0.5635 - val_specificity_metric: 0.5635
# Epoch 26/100
# 11/11 [==============================] - 17s 2s/step - loss: -0.9822 - dice_metric: 0.9891 - jaccard_metric: 0.9784 - sensitivity_metric: 0.9886 - specificity_metric: 0.9886 - val_loss: -0.1242 - val_dice_metric: 0.4941 - val_jaccard_metric: 0.4191 - val_sensitivity_metric: 0.5310 - val_specificity_metric: 0.5310
# Epoch 27/100
# 11/11 [==============================] - 16s 1s/step - loss: -0.9841 - dice_metric: 0.9903 - jaccard_metric: 0.9808 - sensitivity_metric: 0.9903 - specificity_metric: 0.9903 - val_loss: -0.1228 - val_dice_metric: 0.4982 - val_jaccard_metric: 0.4216 - val_sensitivity_metric: 0.5330 - val_specificity_metric: 0.5330
# Epoch 28/100
# 11/11 [==============================] - 17s 2s/step - loss: -0.9852 - dice_metric: 0.9910 - jaccard_metric: 0.9822 - sensitivity_metric: 0.9915 - specificity_metric: 0.9915 - val_loss: -0.1260 - val_dice_metric: 0.5000 - val_jaccard_metric: 0.4234 - val_sensitivity_metric: 0.5349 - val_specificity_metric: 0.5349
# Epoch 29/100
# 11/11 [==============================] - 15s 1s/step - loss: -0.9856 - dice_metric: 0.9912 - jaccard_metric: 0.9827 - sensitivity_metric: 0.9918 - specificity_metric: 0.9918 - val_loss: -0.1437 - val_dice_metric: 0.5076 - val_jaccard_metric: 0.4279 - val_sensitivity_metric: 0.5386 - val_specificity_metric: 0.5386
# Epoch 30/100
# 11/11 [==============================] - 16s 1s/step - loss: -0.9857 - dice_metric: 0.9913 - jaccard_metric: 0.9828 - sensitivity_metric: 0.9913 - specificity_metric: 0.9913 - val_loss: -0.1511 - val_dice_metric: 0.5109 - val_jaccard_metric: 0.4305 - val_sensitivity_metric: 0.5411 - val_specificity_metric: 0.5411
# Epoch 31/100
# 11/11 [==============================] - 17s 2s/step - loss: -0.9862 - dice_metric: 0.9916 - jaccard_metric: 0.9834 - sensitivity_metric: 0.9913 - specificity_metric: 0.9913 - val_loss: -0.1635 - val_dice_metric: 0.5141 - val_jaccard_metric: 0.4333 - val_sensitivity_metric: 0.5436 - val_specificity_metric: 0.5436
# Epoch 32/100
# 11/11 [==============================] - 16s 1s/step - loss: -0.9862 - dice_metric: 0.9916 - jaccard_metric: 0.9833 - sensitivity_metric: 0.9916 - specificity_metric: 0.9916 - val_loss: -0.1570 - val_dice_metric: 0.5154 - val_jaccard_metric: 0.4353 - val_sensitivity_metric: 0.5458 - val_specificity_metric: 0.5458
# Epoch 33/100
# 11/11 [==============================] - 16s 1s/step - loss: -0.9864 - dice_metric: 0.9917 - jaccard_metric: 0.9835 - sensitivity_metric: 0.9925 - specificity_metric: 0.9925 - val_loss: -0.1790 - val_dice_metric: 0.5302 - val_jaccard_metric: 0.4455 - val_sensitivity_metric: 0.5547 - val_specificity_metric: 0.5547
# Epoch 34/100
# 11/11 [==============================] - 19s 2s/step - loss: -0.9862 - dice_metric: 0.9915 - jaccard_metric: 0.9833 - sensitivity_metric: 0.9922 - specificity_metric: 0.9922 - val_loss: -0.1729 - val_dice_metric: 0.5338 - val_jaccard_metric: 0.4494 - val_sensitivity_metric: 0.5579 - val_specificity_metric: 0.5579
# Epoch 35/100
# 11/11 [==============================] - 17s 2s/step - loss: -0.9856 - dice_metric: 0.9911 - jaccard_metric: 0.9825 - sensitivity_metric: 0.9914 - specificity_metric: 0.9914 - val_loss: -0.2194 - val_dice_metric: 0.5577 - val_jaccard_metric: 0.4673 - val_sensitivity_metric: 0.5739 - val_specificity_metric: 0.5739
# Epoch 36/100
# 11/11 [==============================] - 17s 2s/step - loss: -0.9855 - dice_metric: 0.9911 - jaccard_metric: 0.9823 - sensitivity_metric: 0.9906 - specificity_metric: 0.9906 - val_loss: -0.3019 - val_dice_metric: 0.5937 - val_jaccard_metric: 0.4914 - val_sensitivity_metric: 0.5973 - val_specificity_metric: 0.5973
# Epoch 37/100
# 11/11 [==============================] - 18s 2s/step - loss: -0.9849 - dice_metric: 0.9907 - jaccard_metric: 0.9815 - sensitivity_metric: 0.9909 - specificity_metric: 0.9909 - val_loss: -0.1766 - val_dice_metric: 0.5329 - val_jaccard_metric: 0.4475 - val_sensitivity_metric: 0.5560 - val_specificity_metric: 0.5560
# Epoch 38/100
# 11/11 [==============================] - 17s 1s/step - loss: -0.9858 - dice_metric: 0.9912 - jaccard_metric: 0.9827 - sensitivity_metric: 0.9920 - specificity_metric: 0.9920 - val_loss: -0.2201 - val_dice_metric: 0.5572 - val_jaccard_metric: 0.4633 - val_sensitivity_metric: 0.5695 - val_specificity_metric: 0.5695
# Epoch 39/100
# 11/11 [==============================] - 16s 1s/step - loss: -0.9855 - dice_metric: 0.9910 - jaccard_metric: 0.9823 - sensitivity_metric: 0.9912 - specificity_metric: 0.9912 - val_loss: -0.3098 - val_dice_metric: 0.6076 - val_jaccard_metric: 0.5024 - val_sensitivity_metric: 0.6047 - val_specificity_metric: 0.6047
# Epoch 40/100
# 11/11 [==============================] - 16s 1s/step - loss: -0.9871 - dice_metric: 0.9921 - jaccard_metric: 0.9843 - sensitivity_metric: 0.9922 - specificity_metric: 0.9922 - val_loss: -0.2426 - val_dice_metric: 0.5656 - val_jaccard_metric: 0.4693 - val_sensitivity_metric: 0.5743 - val_specificity_metric: 0.5743
# Epoch 41/100
# 11/11 [==============================] - 16s 1s/step - loss: -0.9870 - dice_metric: 0.9920 - jaccard_metric: 0.9843 - sensitivity_metric: 0.9925 - specificity_metric: 0.9925 - val_loss: -0.2428 - val_dice_metric: 0.5620 - val_jaccard_metric: 0.4660 - val_sensitivity_metric: 0.5720 - val_specificity_metric: 0.5720
# Epoch 42/100
# 11/11 [==============================] - 16s 1s/step - loss: -0.9875 - dice_metric: 0.9923 - jaccard_metric: 0.9848 - sensitivity_metric: 0.9928 - specificity_metric: 0.9928 - val_loss: -0.3055 - val_dice_metric: 0.5968 - val_jaccard_metric: 0.4919 - val_sensitivity_metric: 0.5963 - val_specificity_metric: 0.5963
# Epoch 43/100
# 11/11 [==============================] - 16s 1s/step - loss: -0.9872 - dice_metric: 0.9922 - jaccard_metric: 0.9845 - sensitivity_metric: 0.9918 - specificity_metric: 0.9918 - val_loss: -0.3123 - val_dice_metric: 0.6037 - val_jaccard_metric: 0.4979 - val_sensitivity_metric: 0.6021 - val_specificity_metric: 0.6021
# Epoch 44/100
# 11/11 [==============================] - 17s 1s/step - loss: -0.9869 - dice_metric: 0.9919 - jaccard_metric: 0.9839 - sensitivity_metric: 0.9917 - specificity_metric: 0.9917 - val_loss: -0.2865 - val_dice_metric: 0.5896 - val_jaccard_metric: 0.4872 - val_sensitivity_metric: 0.5911 - val_specificity_metric: 0.5911
# Epoch 45/100
# 11/11 [==============================] - 17s 2s/step - loss: -0.9870 - dice_metric: 0.9919 - jaccard_metric: 0.9841 - sensitivity_metric: 0.9926 - specificity_metric: 0.9926 - val_loss: -0.1930 - val_dice_metric: 0.5407 - val_jaccard_metric: 0.4504 - val_sensitivity_metric: 0.5576 - val_specificity_metric: 0.5576
# Epoch 46/100
# 11/11 [==============================] - 18s 2s/step - loss: -0.9869 - dice_metric: 0.9920 - jaccard_metric: 0.9841 - sensitivity_metric: 0.9932 - specificity_metric: 0.9932 - val_loss: -0.2599 - val_dice_metric: 0.5717 - val_jaccard_metric: 0.4728 - val_sensitivity_metric: 0.5770 - val_specificity_metric: 0.5770
# Epoch 47/100
# 11/11 [==============================] - 15s 1s/step - loss: -0.9864 - dice_metric: 0.9916 - jaccard_metric: 0.9834 - sensitivity_metric: 0.9915 - specificity_metric: 0.9915 - val_loss: -0.3977 - val_dice_metric: 0.6398 - val_jaccard_metric: 0.5295 - val_sensitivity_metric: 0.6309 - val_specificity_metric: 0.6309
# Epoch 48/100
# 11/11 [==============================] - 17s 2s/step - loss: -0.9876 - dice_metric: 0.9924 - jaccard_metric: 0.9849 - sensitivity_metric: 0.9915 - specificity_metric: 0.9915 - val_loss: -0.3827 - val_dice_metric: 0.6323 - val_jaccard_metric: 0.5242 - val_sensitivity_metric: 0.6256 - val_specificity_metric: 0.6256
# Epoch 49/100
# 11/11 [==============================] - 17s 1s/step - loss: -0.9867 - dice_metric: 0.9918 - jaccard_metric: 0.9838 - sensitivity_metric: 0.9919 - specificity_metric: 0.9919 - val_loss: -0.3125 - val_dice_metric: 0.5979 - val_jaccard_metric: 0.4946 - val_sensitivity_metric: 0.5967 - val_specificity_metric: 0.5967
# Epoch 50/100
# 11/11 [==============================] - 15s 1s/step - loss: -0.9877 - dice_metric: 0.9924 - jaccard_metric: 0.9850 - sensitivity_metric: 0.9940 - specificity_metric: 0.9940 - val_loss: -0.2406 - val_dice_metric: 0.5642 - val_jaccard_metric: 0.4686 - val_sensitivity_metric: 0.5730 - val_specificity_metric: 0.5730
# Learning rate changed to 1e-05 at epoch 50
# Epoch 51/100
# 11/11 [==============================] - 18s 2s/step - loss: -0.9870 - dice_metric: 0.9921 - jaccard_metric: 0.9844 - sensitivity_metric: 0.9893 - specificity_metric: 0.9893 - val_loss: -0.3451 - val_dice_metric: 0.6089 - val_jaccard_metric: 0.5060 - val_sensitivity_metric: 0.6067 - val_specificity_metric: 0.6067
# Epoch 52/100
# 11/11 [==============================] - 16s 1s/step - loss: -0.9900 - dice_metric: 0.9939 - jaccard_metric: 0.9880 - sensitivity_metric: 0.9941 - specificity_metric: 0.9941 - val_loss: -0.4300 - val_dice_metric: 0.6442 - val_jaccard_metric: 0.5377 - val_sensitivity_metric: 0.6374 - val_specificity_metric: 0.6374
# Epoch 53/100
# 11/11 [==============================] - 17s 2s/step - loss: -0.9905 - dice_metric: 0.9943 - jaccard_metric: 0.9886 - sensitivity_metric: 0.9953 - specificity_metric: 0.9953 - val_loss: -0.4519 - val_dice_metric: 0.6523 - val_jaccard_metric: 0.5458 - val_sensitivity_metric: 0.6439 - val_specificity_metric: 0.6439
# Epoch 54/100
# 11/11 [==============================] - 17s 2s/step - loss: -0.9910 - dice_metric: 0.9946 - jaccard_metric: 0.9893 - sensitivity_metric: 0.9948 - specificity_metric: 0.9948 - val_loss: -0.4698 - val_dice_metric: 0.6605 - val_jaccard_metric: 0.5539 - val_sensitivity_metric: 0.6501 - val_specificity_metric: 0.6501
# Epoch 55/100
# 11/11 [==============================] - 17s 1s/step - loss: -0.9911 - dice_metric: 0.9947 - jaccard_metric: 0.9894 - sensitivity_metric: 0.9946 - specificity_metric: 0.9946 - val_loss: -0.5111 - val_dice_metric: 0.6843 - val_jaccard_metric: 0.5761 - val_sensitivity_metric: 0.6702 - val_specificity_metric: 0.6702
# Epoch 56/100
# 11/11 [==============================] - 17s 1s/step - loss: -0.9912 - dice_metric: 0.9948 - jaccard_metric: 0.9896 - sensitivity_metric: 0.9949 - specificity_metric: 0.9949 - val_loss: -0.5497 - val_dice_metric: 0.7093 - val_jaccard_metric: 0.5993 - val_sensitivity_metric: 0.6915 - val_specificity_metric: 0.6915
# Epoch 57/100
# 11/11 [==============================] - 18s 2s/step - loss: -0.9913 - dice_metric: 0.9948 - jaccard_metric: 0.9897 - sensitivity_metric: 0.9951 - specificity_metric: 0.9951 - val_loss: -0.5826 - val_dice_metric: 0.7358 - val_jaccard_metric: 0.6246 - val_sensitivity_metric: 0.7140 - val_specificity_metric: 0.7140
# Epoch 58/100
# 11/11 [==============================] - 17s 2s/step - loss: -0.9914 - dice_metric: 0.9949 - jaccard_metric: 0.9899 - sensitivity_metric: 0.9950 - specificity_metric: 0.9950 - val_loss: -0.6126 - val_dice_metric: 0.7564 - val_jaccard_metric: 0.6460 - val_sensitivity_metric: 0.7327 - val_specificity_metric: 0.7327
# Epoch 59/100
# 11/11 [==============================] - 17s 2s/step - loss: -0.9915 - dice_metric: 0.9949 - jaccard_metric: 0.9899 - sensitivity_metric: 0.9951 - specificity_metric: 0.9951 - val_loss: -0.6422 - val_dice_metric: 0.7760 - val_jaccard_metric: 0.6674 - val_sensitivity_metric: 0.7517 - val_specificity_metric: 0.7517
# Epoch 60/100
# 11/11 [==============================] - 17s 1s/step - loss: -0.9915 - dice_metric: 0.9950 - jaccard_metric: 0.9900 - sensitivity_metric: 0.9952 - specificity_metric: 0.9952 - val_loss: -0.6698 - val_dice_metric: 0.7918 - val_jaccard_metric: 0.6857 - val_sensitivity_metric: 0.7678 - val_specificity_metric: 0.7678
# Epoch 61/100
# 11/11 [==============================] - 16s 1s/step - loss: -0.9916 - dice_metric: 0.9950 - jaccard_metric: 0.9901 - sensitivity_metric: 0.9952 - specificity_metric: 0.9952 - val_loss: -0.6937 - val_dice_metric: 0.8048 - val_jaccard_metric: 0.7014 - val_sensitivity_metric: 0.7817 - val_specificity_metric: 0.7817
# Epoch 62/100
# 11/11 [==============================] - 15s 1s/step - loss: -0.9916 - dice_metric: 0.9951 - jaccard_metric: 0.9902 - sensitivity_metric: 0.9952 - specificity_metric: 0.9952 - val_loss: -0.7147 - val_dice_metric: 0.8163 - val_jaccard_metric: 0.7155 - val_sensitivity_metric: 0.7942 - val_specificity_metric: 0.7942
# Epoch 63/100
# 11/11 [==============================] - 15s 1s/step - loss: -0.9917 - dice_metric: 0.9951 - jaccard_metric: 0.9902 - sensitivity_metric: 0.9953 - specificity_metric: 0.9953 - val_loss: -0.7322 - val_dice_metric: 0.8272 - val_jaccard_metric: 0.7294 - val_sensitivity_metric: 0.8061 - val_specificity_metric: 0.8061
# Epoch 64/100
# 11/11 [==============================] - 17s 2s/step - loss: -0.9917 - dice_metric: 0.9951 - jaccard_metric: 0.9903 - sensitivity_metric: 0.9953 - specificity_metric: 0.9953 - val_loss: -0.7494 - val_dice_metric: 0.8371 - val_jaccard_metric: 0.7416 - val_sensitivity_metric: 0.8170 - val_specificity_metric: 0.8170
# Epoch 65/100
# 11/11 [==============================] - 15s 1s/step - loss: -0.9918 - dice_metric: 0.9952 - jaccard_metric: 0.9904 - sensitivity_metric: 0.9953 - specificity_metric: 0.9953 - val_loss: -0.7688 - val_dice_metric: 0.8483 - val_jaccard_metric: 0.7552 - val_sensitivity_metric: 0.8292 - val_specificity_metric: 0.8292
# Epoch 66/100
# 11/11 [==============================] - 16s 1s/step - loss: -0.9918 - dice_metric: 0.9952 - jaccard_metric: 0.9904 - sensitivity_metric: 0.9954 - specificity_metric: 0.9954 - val_loss: -0.7885 - val_dice_metric: 0.8590 - val_jaccard_metric: 0.7688 - val_sensitivity_metric: 0.8419 - val_specificity_metric: 0.8419
# Epoch 67/100
# 11/11 [==============================] - 17s 1s/step - loss: -0.9918 - dice_metric: 0.9952 - jaccard_metric: 0.9905 - sensitivity_metric: 0.9954 - specificity_metric: 0.9954 - val_loss: -0.8070 - val_dice_metric: 0.8695 - val_jaccard_metric: 0.7826 - val_sensitivity_metric: 0.8548 - val_specificity_metric: 0.8548
# Epoch 68/100
# 11/11 [==============================] - 16s 1s/step - loss: -0.9919 - dice_metric: 0.9952 - jaccard_metric: 0.9905 - sensitivity_metric: 0.9954 - specificity_metric: 0.9954 - val_loss: -0.8233 - val_dice_metric: 0.8787 - val_jaccard_metric: 0.7952 - val_sensitivity_metric: 0.8662 - val_specificity_metric: 0.8662
# Epoch 69/100
# 11/11 [==============================] - 17s 2s/step - loss: -0.9919 - dice_metric: 0.9953 - jaccard_metric: 0.9906 - sensitivity_metric: 0.9954 - specificity_metric: 0.9954 - val_loss: -0.8385 - val_dice_metric: 0.8875 - val_jaccard_metric: 0.8080 - val_sensitivity_metric: 0.8769 - val_specificity_metric: 0.8769
# Epoch 70/100
# 11/11 [==============================] - 16s 1s/step - loss: -0.9920 - dice_metric: 0.9953 - jaccard_metric: 0.9906 - sensitivity_metric: 0.9955 - specificity_metric: 0.9955 - val_loss: -0.8519 - val_dice_metric: 0.8956 - val_jaccard_metric: 0.8202 - val_sensitivity_metric: 0.8862 - val_specificity_metric: 0.8862
# Epoch 71/100
# 11/11 [==============================] - 17s 2s/step - loss: -0.9920 - dice_metric: 0.9953 - jaccard_metric: 0.9907 - sensitivity_metric: 0.9955 - specificity_metric: 0.9955 - val_loss: -0.8640 - val_dice_metric: 0.9032 - val_jaccard_metric: 0.8320 - val_sensitivity_metric: 0.8954 - val_specificity_metric: 0.8954
# Epoch 72/100
# 11/11 [==============================] - 17s 2s/step - loss: -0.9920 - dice_metric: 0.9953 - jaccard_metric: 0.9907 - sensitivity_metric: 0.9955 - specificity_metric: 0.9955 - val_loss: -0.8740 - val_dice_metric: 0.9102 - val_jaccard_metric: 0.8425 - val_sensitivity_metric: 0.9037 - val_specificity_metric: 0.9037
# Epoch 73/100
# 11/11 [==============================] - 19s 2s/step - loss: -0.9920 - dice_metric: 0.9953 - jaccard_metric: 0.9907 - sensitivity_metric: 0.9955 - specificity_metric: 0.9955 - val_loss: -0.8807 - val_dice_metric: 0.9143 - val_jaccard_metric: 0.8486 - val_sensitivity_metric: 0.9092 - val_specificity_metric: 0.9092
# Epoch 74/100
# 11/11 [==============================] - 16s 1s/step - loss: -0.9921 - dice_metric: 0.9954 - jaccard_metric: 0.9908 - sensitivity_metric: 0.9955 - specificity_metric: 0.9955 - val_loss: -0.8853 - val_dice_metric: 0.9162 - val_jaccard_metric: 0.8515 - val_sensitivity_metric: 0.9121 - val_specificity_metric: 0.9121
# Epoch 75/100
# 11/11 [==============================] - 16s 1s/step - loss: -0.9921 - dice_metric: 0.9954 - jaccard_metric: 0.9908 - sensitivity_metric: 0.9956 - specificity_metric: 0.9956 - val_loss: -0.8903 - val_dice_metric: 0.9184 - val_jaccard_metric: 0.8549 - val_sensitivity_metric: 0.9152 - val_specificity_metric: 0.9152
# Epoch 76/100
# 11/11 [==============================] - 17s 2s/step - loss: -0.9921 - dice_metric: 0.9954 - jaccard_metric: 0.9909 - sensitivity_metric: 0.9956 - specificity_metric: 0.9956 - val_loss: -0.8949 - val_dice_metric: 0.9214 - val_jaccard_metric: 0.8596 - val_sensitivity_metric: 0.9182 - val_specificity_metric: 0.9182
# Epoch 77/100
# 11/11 [==============================] - 17s 1s/step - loss: -0.9922 - dice_metric: 0.9954 - jaccard_metric: 0.9909 - sensitivity_metric: 0.9956 - specificity_metric: 0.9956 - val_loss: -0.8994 - val_dice_metric: 0.9249 - val_jaccard_metric: 0.8653 - val_sensitivity_metric: 0.9218 - val_specificity_metric: 0.9218
# Epoch 78/100
# 11/11 [==============================] - 16s 1s/step - loss: -0.9922 - dice_metric: 0.9954 - jaccard_metric: 0.9909 - sensitivity_metric: 0.9956 - specificity_metric: 0.9956 - val_loss: -0.9037 - val_dice_metric: 0.9292 - val_jaccard_metric: 0.8720 - val_sensitivity_metric: 0.9258 - val_specificity_metric: 0.9258
# Epoch 79/100
# 11/11 [==============================] - 16s 1s/step - loss: -0.9922 - dice_metric: 0.9955 - jaccard_metric: 0.9910 - sensitivity_metric: 0.9956 - specificity_metric: 0.9956 - val_loss: -0.9069 - val_dice_metric: 0.9331 - val_jaccard_metric: 0.8784 - val_sensitivity_metric: 0.9295 - val_specificity_metric: 0.9295
# Epoch 80/100
# 11/11 [==============================] - 18s 2s/step - loss: -0.9923 - dice_metric: 0.9955 - jaccard_metric: 0.9910 - sensitivity_metric: 0.9957 - specificity_metric: 0.9957 - val_loss: -0.9097 - val_dice_metric: 0.9362 - val_jaccard_metric: 0.8835 - val_sensitivity_metric: 0.9324 - val_specificity_metric: 0.9324
# Epoch 81/100
# 11/11 [==============================] - 16s 1s/step - loss: -0.9923 - dice_metric: 0.9955 - jaccard_metric: 0.9911 - sensitivity_metric: 0.9957 - specificity_metric: 0.9957 - val_loss: -0.9125 - val_dice_metric: 0.9386 - val_jaccard_metric: 0.8876 - val_sensitivity_metric: 0.9348 - val_specificity_metric: 0.9348
# Epoch 82/100
# 11/11 [==============================] - 18s 2s/step - loss: -0.9923 - dice_metric: 0.9955 - jaccard_metric: 0.9911 - sensitivity_metric: 0.9957 - specificity_metric: 0.9957 - val_loss: -0.9151 - val_dice_metric: 0.9411 - val_jaccard_metric: 0.8917 - val_sensitivity_metric: 0.9376 - val_specificity_metric: 0.9376
# Epoch 83/100
# 11/11 [==============================] - 18s 2s/step - loss: -0.9923 - dice_metric: 0.9955 - jaccard_metric: 0.9911 - sensitivity_metric: 0.9957 - specificity_metric: 0.9957 - val_loss: -0.9183 - val_dice_metric: 0.9443 - val_jaccard_metric: 0.8972 - val_sensitivity_metric: 0.9412 - val_specificity_metric: 0.9412
# Epoch 84/100
# 11/11 [==============================] - 15s 1s/step - loss: -0.9924 - dice_metric: 0.9956 - jaccard_metric: 0.9912 - sensitivity_metric: 0.9957 - specificity_metric: 0.9957 - val_loss: -0.9214 - val_dice_metric: 0.9475 - val_jaccard_metric: 0.9026 - val_sensitivity_metric: 0.9446 - val_specificity_metric: 0.9446
# Epoch 85/100
# 11/11 [==============================] - 17s 1s/step - loss: -0.9924 - dice_metric: 0.9956 - jaccard_metric: 0.9912 - sensitivity_metric: 0.9957 - specificity_metric: 0.9957 - val_loss: -0.9240 - val_dice_metric: 0.9499 - val_jaccard_metric: 0.9067 - val_sensitivity_metric: 0.9472 - val_specificity_metric: 0.9472
# Epoch 86/100
# 11/11 [==============================] - 15s 1s/step - loss: -0.9924 - dice_metric: 0.9956 - jaccard_metric: 0.9912 - sensitivity_metric: 0.9958 - specificity_metric: 0.9958 - val_loss: -0.9259 - val_dice_metric: 0.9506 - val_jaccard_metric: 0.9079 - val_sensitivity_metric: 0.9479 - val_specificity_metric: 0.9479
# Epoch 87/100
# 11/11 [==============================] - 16s 1s/step - loss: -0.9924 - dice_metric: 0.9956 - jaccard_metric: 0.9913 - sensitivity_metric: 0.9958 - specificity_metric: 0.9958 - val_loss: -0.9274 - val_dice_metric: 0.9508 - val_jaccard_metric: 0.9083 - val_sensitivity_metric: 0.9481 - val_specificity_metric: 0.9481
# Epoch 88/100
# 11/11 [==============================] - 18s 2s/step - loss: -0.9925 - dice_metric: 0.9956 - jaccard_metric: 0.9913 - sensitivity_metric: 0.9958 - specificity_metric: 0.9958 - val_loss: -0.9278 - val_dice_metric: 0.9503 - val_jaccard_metric: 0.9075 - val_sensitivity_metric: 0.9478 - val_specificity_metric: 0.9478
# Epoch 89/100
# 11/11 [==============================] - 16s 1s/step - loss: -0.9925 - dice_metric: 0.9956 - jaccard_metric: 0.9913 - sensitivity_metric: 0.9958 - specificity_metric: 0.9958 - val_loss: -0.9286 - val_dice_metric: 0.9505 - val_jaccard_metric: 0.9080 - val_sensitivity_metric: 0.9479 - val_specificity_metric: 0.9479
# Epoch 90/100
# 11/11 [==============================] - 17s 1s/step - loss: -0.9925 - dice_metric: 0.9957 - jaccard_metric: 0.9914 - sensitivity_metric: 0.9958 - specificity_metric: 0.9958 - val_loss: -0.9293 - val_dice_metric: 0.9508 - val_jaccard_metric: 0.9085 - val_sensitivity_metric: 0.9483 - val_specificity_metric: 0.9483
# Epoch 91/100
# 11/11 [==============================] - 17s 1s/step - loss: -0.9925 - dice_metric: 0.9957 - jaccard_metric: 0.9914 - sensitivity_metric: 0.9958 - specificity_metric: 0.9958 - val_loss: -0.9298 - val_dice_metric: 0.9510 - val_jaccard_metric: 0.9087 - val_sensitivity_metric: 0.9484 - val_specificity_metric: 0.9484
# Epoch 92/100
# 11/11 [==============================] - 15s 1s/step - loss: -0.9926 - dice_metric: 0.9957 - jaccard_metric: 0.9914 - sensitivity_metric: 0.9959 - specificity_metric: 0.9959 - val_loss: -0.9306 - val_dice_metric: 0.9516 - val_jaccard_metric: 0.9099 - val_sensitivity_metric: 0.9489 - val_specificity_metric: 0.9489
# Epoch 93/100
# 11/11 [==============================] - 20s 2s/step - loss: -0.9926 - dice_metric: 0.9957 - jaccard_metric: 0.9915 - sensitivity_metric: 0.9959 - specificity_metric: 0.9959 - val_loss: -0.9320 - val_dice_metric: 0.9526 - val_jaccard_metric: 0.9114 - val_sensitivity_metric: 0.9497 - val_specificity_metric: 0.9497
# Epoch 94/100
# 11/11 [==============================] - 16s 1s/step - loss: -0.9926 - dice_metric: 0.9957 - jaccard_metric: 0.9915 - sensitivity_metric: 0.9959 - specificity_metric: 0.9959 - val_loss: -0.9332 - val_dice_metric: 0.9530 - val_jaccard_metric: 0.9122 - val_sensitivity_metric: 0.9504 - val_specificity_metric: 0.9504
# Epoch 95/100
# 11/11 [==============================] - 16s 1s/step - loss: -0.9926 - dice_metric: 0.9957 - jaccard_metric: 0.9915 - sensitivity_metric: 0.9959 - specificity_metric: 0.9959 - val_loss: -0.9342 - val_dice_metric: 0.9532 - val_jaccard_metric: 0.9127 - val_sensitivity_metric: 0.9508 - val_specificity_metric: 0.9508
# Epoch 96/100
# 11/11 [==============================] - 15s 1s/step - loss: -0.9927 - dice_metric: 0.9958 - jaccard_metric: 0.9916 - sensitivity_metric: 0.9959 - specificity_metric: 0.9959 - val_loss: -0.9350 - val_dice_metric: 0.9532 - val_jaccard_metric: 0.9127 - val_sensitivity_metric: 0.9506 - val_specificity_metric: 0.9506
# Epoch 97/100
# 11/11 [==============================] - 15s 1s/step - loss: -0.9927 - dice_metric: 0.9958 - jaccard_metric: 0.9916 - sensitivity_metric: 0.9959 - specificity_metric: 0.9959 - val_loss: -0.9354 - val_dice_metric: 0.9534 - val_jaccard_metric: 0.9132 - val_sensitivity_metric: 0.9505 - val_specificity_metric: 0.9505
# Epoch 98/100
# 11/11 [==============================] - 15s 1s/step - loss: -0.9927 - dice_metric: 0.9958 - jaccard_metric: 0.9916 - sensitivity_metric: 0.9960 - specificity_metric: 0.9960 - val_loss: -0.9361 - val_dice_metric: 0.9548 - val_jaccard_metric: 0.9157 - val_sensitivity_metric: 0.9521 - val_specificity_metric: 0.9521
# Epoch 99/100
# 11/11 [==============================] - 18s 2s/step - loss: -0.9927 - dice_metric: 0.9958 - jaccard_metric: 0.9917 - sensitivity_metric: 0.9960 - specificity_metric: 0.9960 - val_loss: -0.9366 - val_dice_metric: 0.9559 - val_jaccard_metric: 0.9176 - val_sensitivity_metric: 0.9533 - val_specificity_metric: 0.9533
# Epoch 100/100
# 11/11 [==============================] - 18s 2s/step - loss: -0.9928 - dice_metric: 0.9958 - jaccard_metric: 0.9917 - sensitivity_metric: 0.9960 - specificity_metric: 0.9960 - val_loss: -0.9372 - val_dice_metric: 0.9566 - val_jaccard_metric: 0.9187 - val_sensitivity_metric: 0.9541 - val_specificity_metric: 0.9541

# %%
model.save(f"{config['Seg_model']}_{config['Activation']}_{config['Dataset']}.keras")

# %% [markdown]
# ### **Guardando modelo en TF_LITE**

# %%
#'model' es tu modelo entrenado
converter = tf.lite.TFLiteConverter.from_keras_model(model)

# Opcional: activar optimizaciones para reducir el tamaño y mejorar la velocidad
converter.optimizations = [tf.lite.Optimize.DEFAULT]

# Realiza la conversión
tflite_model = converter.convert()

# Guarda el modelo TF Lite en un archivo .tflite
tflite_model_file = f"{config['Seg_model']}_{config['Activation']}_{config['Dataset']}.tflite"
with open(tflite_model_file, "wb") as f:
    f.write(tflite_model)

# %% [markdown]
# ### **Desempeño del modelo**

# %% [markdown]
# #### **Visualización de las inferencias del modelo Keras**

# %%
def performance_visualization(dataset, model, config):

    # Select a random batch index
    batch = 0

    # Skip to the desired batch and take one batch
    for images, masks in dataset.skip(batch).take(1):
        print(f"Images in the batch: {images.shape}, Masks in the batch: {masks.shape}")

    # Select a random sample within the batch
    sample = random.randint(0, images.shape[0]-1)

    predictions = model(images[sample:sample+1,...], training=False)

    # Determine the number of columns for the visualization grid

    columns = []
    rows = 3

    columns.append(masks.shape[-1] if masks.shape[-1] <= 6 else 6)
    
    columns = max(columns)

    fig = plt.figure(figsize=(20, 12))
    gs = fig.add_gridspec(rows + 1, columns, hspace=0.2, wspace=-0.6)
    axes = [[fig.add_subplot(gs[r, c]) for c in range(columns)] for r in range(rows)]

    # Display the original image for the selected sample
    axes[0][0].set_title('Image',loc='center')
    axes[0][0].imshow(images[sample])  # Show the sample image

    title_ax = fig.add_subplot(gs[rows-2, :])
    title_ax.set_title("Original masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-2][i].imshow(masks[sample, :, :,classes_list[i]:classes_list[i]+1])

    title_ax = fig.add_subplot(gs[rows-1, :])
    title_ax.set_title("Predicted masks of segmentation for different classes",loc='center')
    title_ax.axis('off')  # Ocultar ejes

    classes_list = []
    while len(classes_list) < min(config['Number of classes'],columns):
        num = random.randint(0, config['Number of classes']-1)
        if num not in classes_list:
            classes_list.append(num)

    for i in range(len(classes_list)):
        axes[rows-1][i].imshow(tf.where(predictions[0, :, :,classes_list[i]:classes_list[i]+1] >0.5, 1.0, 0.0))

    [ax.axis('off') for row in axes for ax in row]

    # Adjust layout for better spacing
    fig.tight_layout()

    # Display the visualization
    plt.show()
    # Free memory
    del images, predictions, classes_list, masks# Delete large variables
    gc.collect() # Force garbage collection

# %%
performance_visualization(test_dataset, model, config)
# Out:
# Images in the batch: (32, 512, 512, 3), Masks in the batch: (32, 512, 512, 2)
# <ipython-input-20-8da1dc506d2d>:61: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# #### **Rendimiento del modelo para datos de evaluación**

# %%
def performance_measures(model,dataset,config,save_results=True):

    with tf.device('/GPU:0' if tf.config.list_physical_devices('GPU') else '/CPU:0'):
        # Initialize empty lists to store metric results
        dice_results = []
        jaccard_results = []
        sensitivity_results = []
        specificity_results = []

        # Process each batch in the dataset
        for data_batch in dataset:
            images, masks = data_batch

            # Generate model predictions
            y_pred = model(images, training=False)

            # Assume the model's prediction covers all classes
            y_pred_class = y_pred[...,:config['Number of classes']]
            dice_batch = dice_metric(masks, y_pred_class, return_mean=False)
            jaccard_batch = jaccard_metric(masks, y_pred_class, return_mean=False)
            sensitivity_batch = sensitivity_metric(masks, y_pred_class, return_mean=False)
            specificity_batch = specificity_metric(masks, y_pred_class, return_mean=False)
            
            # Store results from the current batch
            dice_results.append(dice_batch.numpy().flatten())
            jaccard_results.append(jaccard_batch.numpy().flatten())
            sensitivity_results.append(sensitivity_batch.numpy().flatten())
            specificity_results.append(specificity_batch.numpy().flatten())

            # Free memory by deleting unnecessary tensors immediately
            del y_pred, y_pred_class, dice_batch, jaccard_batch, sensitivity_batch, specificity_batch, images, masks

        # Convert lists of batches to flat NumPy arrays for analysis
        dice_results = np.concatenate(dice_results)
        jaccard_results = np.concatenate(jaccard_results)
        sensitivity_results = np.concatenate(sensitivity_results)
        specificity_results = np.concatenate(specificity_results)

        # Print performance summaries with 5 decimal places precision
        print("Model's performance metrics:")
        print(f"Dice Coefficient mean: {np.mean(dice_results):.5f}, standard deviation: {np.std(dice_results):.5f}")
        print(f"Jaccard Index mean: {np.mean(jaccard_results):.5f}, standard deviation: {np.std(jaccard_results):.5f}")
        print(f"Sensitivity mean: {np.mean(sensitivity_results):.5f}, standard deviation: {np.std(sensitivity_results):.5f}")
        print(f"Specificity mean: {np.mean(specificity_results):.5f}, standard deviation: {np.std(specificity_results):.5f}")

        # Save results to disk if requested
        if save_results:
            # Check if the directory exists, and if not, create it
            if not os.path.exists('./results'):
                os.makedirs('./results')

            # Generate filenames using the configuration parameters
            filename_base = f"./results/{config['Seg_model']}_{config['Activation']}_{config['Dataset']}"
            np.save(f"{filename_base}_DICE.npy", dice_results)
            np.save(f"{filename_base}_Jaccard.npy", jaccard_results)
            np.save(f"{filename_base}_Sensitivity.npy", sensitivity_results)
            np.save(f"{filename_base}_Specificity.npy", specificity_results)

        # Cleanup intermediate results to free memory
        gc.collect()
        del dice_results, jaccard_results, sensitivity_results, specificity_results
        return [f"{filename_base}_DICE.npy", f"{filename_base}_Jaccard.npy", f"{filename_base}_Sensitivity.npy", f"{filename_base}_Specificity.npy"]

# %%
metrics = performance_measures(model,test_dataset,config,save_results=True)
# Out:
# Model's performance metrics:
# Dice Coefficient mean: 0.96213, standard deviation: 0.03513
# Jaccard Index mean: 0.92907, standard deviation: 0.06068
# Sensitivity mean: 0.96298, standard deviation: 0.04357
# Specificity mean: 0.96298, standard deviation: 0.04357
